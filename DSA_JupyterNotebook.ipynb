# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sys
import matplotlib
from numpy.random import RandomState

rand = RandomState()

# %%
from epidemiccore_w import Epidemic

# %%
import os as os 
Root_Folder = os.getcwd()
Plot_Folder = os.path.join(Root_Folder,'plots')

# %%
def fig_save(fig, Plot_Folder, fname):
    fig.savefig(os.path.join (Plot_Folder, fname),dpi=300)
    fig.savefig (os.path.join (Plot_Folder, fname + "." + 'pdf'), format='pdf')
    # fig.savefig (os.path.join (Plot_Folder, fname + "." + 'svg'), format='svg')
    fig.savefig (os.path.join (Plot_Folder, fname + "." + 'eps'), format='eps', dpi=1000)

# %%
'''
# USA data
'''
usa_file = 'US0318.csv'
df_usa = pd.read_csv(usa_file)

# %%
inf_count
# Out:
# array([   1,    1,    2,    2,    3,    5,    5,    5,    5,    5,    5,
#           5,    5,   12,   12,   12,   12,   12,   13,   13,   14,   15,
#          15,   15,   15,   15,   15,   15,   15,   34,   34,   34,   53,
#          57,   60,   60,   64,   69,   89,  106,  126,  161,  233,  338,
#         445,  572,  717, 1004, 1323, 1832, 2291, 2995, 3782, 5073, 7038])

# %%
# get daily counts
df_usa_inf = df_usa['cum_confirm'].diff().abs()
df_usa_inf[0] = df_usa['cum_confirm'].iloc[0]
df_usa['daily_confirm'] = df_usa_inf

inf_count = df_usa['cum_confirm'].values
death_count = df_usa['cum_dead'].values
cure_count = df_usa['cum_heal'].values

# %%
# get daily counts recovery
df_usa_cure = df_usa['cum_heal'].diff().abs()
df_usa_cure[0] = df_usa['cum_heal'].iloc[0]
df_usa['recovery'] = df_usa_cure

# %%
fig_usa = Epidemic.Plot_Data(
	inf_count=inf_count,
	death_count=death_count,
	cure_count=cure_count,
	daily_confirm=df_usa['daily_confirm'].values,
	daily_cure=df_usa['recovery'].values,
	t=np.arange(1,df_usa.shape[0]+1),
	legend='left',
	scale_density=1.0,
	location='United States of America'
)
fname = 'usa'
fig_save(fig_usa,Plot_Folder,fname)
# fig_usa.savefig (os.path.join (Plot_Folder, fname + "." + 'pdf'), format='pdf')
# #fig_usa.savefig (os.path.join (Plot_Folder, fname + "." + 'svg'), format='svg')
# fig_usa.savefig (os.path.join (Plot_Folder, fname + "." + 'eps'), format='eps', dpi=1000)
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# generate infection times through uniformly distributing throughout each day
infection_data = list(i+rand.uniform() for i,y in enumerate(df_usa['daily_confirm'].values) for z in range(y.astype(int)))
df = pd.DataFrame(infection_data,index=range(len(infection_data)),columns=['infection'])

# get daily counts recovery
df_usa_cure = df_usa['cum_heal'].diff().abs()
df_usa_cure[0] = df_usa['cum_heal'].iloc[0]
df_usa['recovery'] = df_usa_cure

# generate recovery times through uniformly distributing throughout each day 
recovery_data = list(i+rand.uniform() for i,y in enumerate(df_usa['recovery'].values) for z in range(y.astype(int)))
df_recovery = pd.DataFrame(recovery_data,index=range(len(recovery_data)),columns=['recovery'])

#file = '20200302_covid_transformed_data.csv'
bounds = [(0.1,1),(0.1,1),(1E-9,1E-1)]
#df = pd.read_csv(file)

N = min(2000,df_usa['cum_confirm'].iloc[-1])
n = 5
plot_T = 150 # show system through end of epidemic

epiT = Epidemic(file_or_df=df,bounds=bounds,abc=(0.4,0.6,1E-8),plot_T=plot_T)
epiT.fit(N=N) # use all the data
# Out:
# theta= [4.e-01 6.e-01 1.e-08] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [4.0000001e-01 6.0000000e-01 1.0000000e-08] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [4.0000000e-01 6.0000001e-01 1.0000000e-08] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [4.e-01 6.e-01 2.e-08] -LogLike= 4788.566510074413 #okay= 2000 #points= 2000
# theta= [0.4 0.6 0.1] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [0.40000001 0.6        0.1       ] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [0.4        0.60000001 0.1       ] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [0.4        0.6        0.10000001] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [0.4        0.6        0.03328338] -LogLike= 20587.806581330016 #okay= 2000 #points= 2000
# theta= [0.40000001 0.6        0.03328338] -LogLike= 20587.806446795446 #okay= 2000 #points= 2000
# theta= [0.4        0.60000001 0.03328338] -LogLike= 20587.80688082928 #okay= 2000 #points= 2000
# theta= [0.4        0.6        0.03328339] -LogLike= 20587.807908681993 #okay= 2000 #points= 2000
# theta= [0.4        0.6        0.01107784] -LogLike= 16742.520875682447 #okay= 2000 #points= 2000
# theta= [0.40000001 0.6        0.01107784] -LogLike= 16742.5205936395 #okay= 2000 #points= 2000
# theta= [0.4        0.60000001 0.01107784] -LogLike= 16742.52125692164 #okay= 2000 #points= 2000
# theta= [0.4        0.6        0.01107785] -LogLike= 16742.52335421389 #okay= 2000 #points= 2000
# theta= [0.4        0.6        0.00368709] -LogLike= 14218.34285962149 #okay= 2000 #points= 2000
# theta= [0.40000001 0.6        0.00368709] -LogLike= 14218.342495661214 #okay= 2000 #points= 2000
# theta= [0.4        0.60000001 0.00368709] -LogLike= 14218.343290044711 #okay= 2000 #points= 2000
# theta= [0.4       0.6       0.0036871] -LogLike= 14218.348164580919 #okay= 2000 #points= 2000
# theta= [0.4       0.6       0.0012272] -LogLike= 12268.545447877235 #okay= 2000 #points= 2000
# theta= [0.40000001 0.6        0.0012272 ] -LogLike= 12268.54503733446 #okay= 2000 #points= 2000
# theta= [0.4        0.60000001 0.0012272 ] -LogLike= 12268.5459067903 #okay= 2000 #points= 2000
# theta= [0.4        0.6        0.00122721] -LogLike= 12268.558789578185 #okay= 2000 #points= 2000
# theta= [4.00000000e-01 6.00000000e-01 4.08467485e-04] -LogLike= 10550.918662689417 #okay= 2000 #points= 2000
# theta= [4.00000010e-01 6.00000000e-01 4.08467485e-04] -LogLike= 10550.9182252416 #okay= 2000 #points= 2000
# theta= [4.00000000e-01 6.00000010e-01 4.08467485e-04] -LogLike= 10550.919136366805 #okay= 2000 #points= 2000
# theta= [4.00000000e-01 6.00000000e-01 4.08477485e-04] -LogLike= 10550.955408723252 #okay= 2000 #points= 2000
# theta= [4.00000000e-01 6.00000000e-01 1.35965035e-04] -LogLike= 8952.551316131236 #okay= 2000 #points= 2000
# theta= [4.00000010e-01 6.00000000e-01 1.35965035e-04] -LogLike= 8952.55087214932 #okay= 2000 #points= 2000
# theta= [4.00000000e-01 6.00000010e-01 1.35965035e-04] -LogLike= 8952.551787065022 #okay= 2000 #points= 2000
# theta= [4.00000000e-01 6.00000000e-01 1.35975035e-04] -LogLike= 8952.654545313328 #okay= 2000 #points= 2000
# theta= [4.00000000e-01 6.00000000e-01 4.52670456e-05] -LogLike= 7482.360553605625 #okay= 2000 #points= 2000
# theta= [4.00000010e-01 6.00000000e-01 4.52670456e-05] -LogLike= 7482.36013965262 #okay= 2000 #points= 2000
# theta= [4.00000000e-01 6.00000010e-01 4.52670456e-05] -LogLike= 7482.360987099793 #okay= 2000 #points= 2000
# theta= [4.00000000e-01 6.00000000e-01 4.52770456e-05] -LogLike= 7482.637476754826 #okay= 2000 #points= 2000
# theta= [4.0000000e-01 6.0000000e-01 1.5079709e-05] -LogLike= 6246.046190381585 #okay= 2000 #points= 2000
# theta= [4.0000001e-01 6.0000000e-01 1.5079709e-05] -LogLike= 6246.045868813981 #okay= 2000 #points= 2000
# theta= [4.0000000e-01 6.0000001e-01 1.5079709e-05] -LogLike= 6246.046525089407 #okay= 2000 #points= 2000
# theta= [4.0000000e-01 6.0000000e-01 1.5089709e-05] -LogLike= 6246.688565940175 #okay= 2000 #points= 2000
# theta= [4.0000000e-01 6.0000000e-01 5.0323595e-06] -LogLike= 5401.699401994969 #okay= 2000 #points= 2000
# theta= [4.0000001e-01 6.0000000e-01 5.0323595e-06] -LogLike= 5401.699227669109 #okay= 2000 #points= 2000
# theta= [4.0000000e-01 6.0000001e-01 5.0323595e-06] -LogLike= 5401.699583469958 #okay= 2000 #points= 2000
# theta= [4.0000000e-01 6.0000000e-01 5.0423595e-06] -LogLike= 5402.813980876579 #okay= 2000 #points= 2000
# theta= [4.00000000e-01 6.00000000e-01 5.03235387e-06] -LogLike= 5401.698774877562 #okay= 2000 #points= 2000
# theta= [4.00000010e-01 6.00000000e-01 5.03235387e-06] -LogLike= 5401.69860056395 #okay= 2000 #points= 2000
# theta= [4.00000000e-01 6.00000010e-01 5.03235387e-06] -LogLike= 5401.6989563259895 #okay= 2000 #points= 2000
# theta= [4.00000000e-01 6.00000000e-01 5.04235387e-06] -LogLike= 5402.81335414757 #okay= 2000 #points= 2000
# theta= [4.00000000e-01 6.00000000e-01 5.03233138e-06] -LogLike= 5401.696266369202 #okay= 2000 #points= 2000
# theta= [4.00000010e-01 6.00000000e-01 5.03233138e-06] -LogLike= 5401.696092056463 #okay= 2000 #points= 2000
# theta= [4.00000000e-01 6.00000010e-01 5.03233138e-06] -LogLike= 5401.696447842587 #okay= 2000 #points= 2000
# theta= [4.00000000e-01 6.00000000e-01 5.04233138e-06] -LogLike= 5402.810847266391 #okay= 2000 #points= 2000
# theta= [4.00000000e-01 6.00000000e-01 5.03224138e-06] -LogLike= 5401.686232294078 #okay= 2000 #points= 2000
# theta= [4.00000010e-01 6.00000000e-01 5.03224138e-06] -LogLike= 5401.686057979002 #okay= 2000 #points= 2000
# theta= [4.00000000e-01 6.00000010e-01 5.03224138e-06] -LogLike= 5401.686413756006 #okay= 2000 #points= 2000
# theta= [4.00000000e-01 6.00000000e-01 5.04224138e-06] -LogLike= 5402.800819730804 #okay= 2000 #points= 2000
# theta= [4.0000000e-01 6.0000000e-01 5.0318814e-06] -LogLike= 5401.646095371656 #okay= 2000 #points= 2000
# theta= [4.0000001e-01 6.0000000e-01 5.0318814e-06] -LogLike= 5401.645921077518 #okay= 2000 #points= 2000
# theta= [4.0000000e-01 6.0000001e-01 5.0318814e-06] -LogLike= 5401.646276832388 #okay= 2000 #points= 2000
# theta= [4.0000000e-01 6.0000000e-01 5.0418814e-06] -LogLike= 5402.7607090388055 #okay= 2000 #points= 2000
# theta= [4.00000000e-01 6.00000000e-01 5.03044146e-06] -LogLike= 5401.48553840904 #okay= 2000 #points= 2000
# theta= [4.00000010e-01 6.00000000e-01 5.03044146e-06] -LogLike= 5401.485364151621 #okay= 2000 #points= 2000
# theta= [4.00000000e-01 6.00000010e-01 5.03044146e-06] -LogLike= 5401.485719830108 #okay= 2000 #points= 2000
# theta= [4.00000000e-01 6.00000000e-01 5.04044146e-06] -LogLike= 5402.600256802857 #okay= 2000 #points= 2000
# theta= [4.00000000e-01 6.00000000e-01 5.02468172e-06] -LogLike= 5400.843159632342 #okay= 2000 #points= 2000
# theta= [4.00000010e-01 6.00000000e-01 5.02468172e-06] -LogLike= 5400.842985518294 #okay= 2000 #points= 2000
# theta= [4.00000000e-01 6.00000010e-01 5.02468172e-06] -LogLike= 5400.843340887142 #okay= 2000 #points= 2000
# theta= [4.00000000e-01 6.00000000e-01 5.03468172e-06] -LogLike= 5401.9582969909925 #okay= 2000 #points= 2000
# theta= [4.00000000e-01 6.00000000e-01 5.00164277e-06] -LogLike= 5398.27122892074 #okay= 2000 #points= 2000
# theta= [4.00000010e-01 6.00000000e-01 5.00164277e-06] -LogLike= 5398.271055451339 #okay= 2000 #points= 2000
# theta= [4.00000000e-01 6.00000010e-01 5.00164277e-06] -LogLike= 5398.271409517103 #okay= 2000 #points= 2000
# theta= [4.00000000e-01 6.00000000e-01 5.01164277e-06] -LogLike= 5399.388043914712 #okay= 2000 #points= 2000
# theta= [4.00000000e-01 6.00000000e-01 4.90948697e-06] -LogLike= 5387.944770562281 #okay= 2000 #points= 2000
# theta= [4.00000010e-01 6.00000000e-01 4.90948697e-06] -LogLike= 5387.94459965784 #okay= 2000 #points= 2000
# theta= [4.00000000e-01 6.00000010e-01 4.90948697e-06] -LogLike= 5387.944948511448 #okay= 2000 #points= 2000
# theta= [4.00000000e-01 6.00000000e-01 4.91948697e-06] -LogLike= 5389.06831749386 #okay= 2000 #points= 2000
# theta= [4.00000000e-01 6.00000000e-01 4.54086374e-06] -LogLike= 5346.011727319114 #okay= 2000 #points= 2000
# theta= [4.00000010e-01 6.00000000e-01 4.54086374e-06] -LogLike= 5346.011567075373 #okay= 2000 #points= 2000
# theta= [4.00000000e-01 6.00000010e-01 4.54086374e-06] -LogLike= 5346.011894232972 #okay= 2000 #points= 2000
# theta= [4.00000000e-01 6.00000000e-01 4.55086374e-06] -LogLike= 5347.1624312345175 #okay= 2000 #points= 2000
# theta= [4.00000000e-01 6.00000000e-01 3.06637084e-06] -LogLike= 5168.21350876616 #okay= 2000 #points= 2000
# theta= [4.00000010e-01 6.00000000e-01 3.06637084e-06] -LogLike= 5168.213398611752 #okay= 2000 #points= 2000
# theta= [4.00000000e-01 6.00000010e-01 3.06637084e-06] -LogLike= 5168.213623809177 #okay= 2000 #points= 2000
# theta= [4.00000000e-01 6.00000000e-01 3.07637084e-06] -LogLike= 5169.4717386175635 #okay= 2000 #points= 2000
# theta= [4.00000001e-01 5.99999999e-01 1.00000000e-09] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [4.00000011e-01 5.99999999e-01 1.00000000e-09] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [4.00000001e-01 6.00000009e-01 1.00000000e-09] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [4.00000001e-01 5.99999999e-01 1.10000000e-08] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [4.00000000e-01 6.00000000e-01 3.06617281e-06] -LogLike= 5168.188584800058 #okay= 2000 #points= 2000
# theta= [4.00000010e-01 6.00000000e-01 3.06617281e-06] -LogLike= 5168.188474612456 #okay= 2000 #points= 2000
# theta= [4.00000000e-01 6.00000010e-01 3.06617281e-06] -LogLike= 5168.188699823681 #okay= 2000 #points= 2000
# theta= [4.00000000e-01 6.00000000e-01 3.07617281e-06] -LogLike= 5169.446827816306 #okay= 2000 #points= 2000
# theta= [4.0000000e-01 6.0000000e-01 3.0659748e-06] -LogLike= 5168.163663438168 #okay= 2000 #points= 2000
# theta= [4.0000001e-01 6.0000000e-01 3.0659748e-06] -LogLike= 5168.1635532836 #okay= 2000 #points= 2000
# theta= [4.0000000e-01 6.0000001e-01 3.0659748e-06] -LogLike= 5168.163778478593 #okay= 2000 #points= 2000
# theta= [4.0000000e-01 6.0000000e-01 3.0759748e-06] -LogLike= 5169.421919666557 #okay= 2000 #points= 2000
# theta= [4.00000001e-01 5.99999999e-01 1.53348740e-06] -LogLike= 4969.49992127069 #okay= 2000 #points= 2000
# theta= [4.00000011e-01 5.99999999e-01 1.53348740e-06] -LogLike= 4969.499877715421 #okay= 2000 #points= 2000
# theta= [4.00000001e-01 6.00000009e-01 1.53348740e-06] -LogLike= 4969.499967266001 #okay= 2000 #points= 2000
# theta= [4.00000001e-01 5.99999999e-01 1.54348740e-06] -LogLike= 4970.812165765064 #okay= 2000 #points= 2000
# theta= [4.00000001e-01 5.99999999e-01 1.53343578e-06] -LogLike= 4969.493147177734 #okay= 2000 #points= 2000
# theta= [4.00000011e-01 5.99999999e-01 1.53343578e-06] -LogLike= 4969.493103623581 #okay= 2000 #points= 2000
# theta= [4.00000001e-01 6.00000009e-01 1.53343578e-06] -LogLike= 4969.493193168198 #okay= 2000 #points= 2000
# theta= [4.00000001e-01 5.99999999e-01 1.54343578e-06] -LogLike= 4970.805389660589 #okay= 2000 #points= 2000
# theta= [4.00000001e-01 5.99999999e-01 1.53166367e-06] -LogLike= 4969.260583149997 #okay= 2000 #points= 2000
# theta= [4.00000011e-01 5.99999999e-01 1.53166367e-06] -LogLike= 4969.260539682142 #okay= 2000 #points= 2000
# theta= [4.00000001e-01 6.00000009e-01 1.53166367e-06] -LogLike= 4969.260629057755 #okay= 2000 #points= 2000
# theta= [4.00000001e-01 5.99999999e-01 1.54166367e-06] -LogLike= 4970.572757175266 #okay= 2000 #points= 2000
# theta= [4.00000001e-01 5.99999999e-01 7.66331836e-07] -LogLike= 4871.305761472003 #okay= 2000 #points= 2000
# theta= [4.00000011e-01 5.99999999e-01 7.66331836e-07] -LogLike= 4871.305754627797 #okay= 2000 #points= 2000
# theta= [4.00000001e-01 6.00000009e-01 7.66331836e-07] -LogLike= 4871.30576949492 #okay= 2000 #points= 2000
# theta= [4.00000001e-01 5.99999999e-01 7.76331836e-07] -LogLike= 4872.542628735709 #okay= 2000 #points= 2000
# theta= [4.00000001e-01 5.99999999e-01 2.61212824e-07] -LogLike= 4812.440365624949 #okay= 2000 #points= 2000
# theta= [4.00000011e-01 5.99999999e-01 2.61212824e-07] -LogLike= 4812.440380050316 #okay= 2000 #points= 2000
# theta= [4.00000001e-01 6.00000009e-01 2.61212824e-07] -LogLike= 4812.440351712808 #okay= 2000 #points= 2000
# theta= [4.00000001e-01 5.99999999e-01 2.71212824e-07] -LogLike= 4813.513505016265 #okay= 2000 #points= 2000
# theta= [4.00000001e-01 5.99999999e-01 2.61212824e-07] -LogLike= 4812.440365624949 #okay= 2000 #points= 2000
# theta= [4.00000011e-01 5.99999999e-01 2.61212824e-07] -LogLike= 4812.440380050316 #okay= 2000 #points= 2000
# theta= [4.00000001e-01 6.00000009e-01 2.61212824e-07] -LogLike= 4812.440351712808 #okay= 2000 #points= 2000
# theta= [4.00000001e-01 5.99999999e-01 2.71212824e-07] -LogLike= 4813.513505016265 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000002e-01 1.00000000e-09] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [4.00000008e-01 6.00000002e-01 1.00000000e-09] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000012e-01 1.00000000e-09] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000002e-01 1.10000000e-08] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [4.00000001e-01 5.99999999e-01 2.61211607e-07] -LogLike= 4812.440235262501 #okay= 2000 #points= 2000
# theta= [4.00000011e-01 5.99999999e-01 2.61211607e-07] -LogLike= 4812.440249538403 #okay= 2000 #points= 2000
# theta= [4.00000001e-01 6.00000009e-01 2.61211607e-07] -LogLike= 4812.440221376627 #okay= 2000 #points= 2000
# theta= [4.00000001e-01 5.99999999e-01 2.71211607e-07] -LogLike= 4813.513374075299 #okay= 2000 #points= 2000
# theta= [3.99999999e-01 6.00000001e-01 1.31105804e-07] -LogLike= 4798.951880235864 #okay= 2000 #points= 2000
# theta= [4.00000009e-01 6.00000001e-01 1.31105804e-07] -LogLike= 4798.951898626197 #okay= 2000 #points= 2000
# theta= [3.99999999e-01 6.00000011e-01 1.31105804e-07] -LogLike= 4798.951861911323 #okay= 2000 #points= 2000
# theta= [3.99999999e-01 6.00000001e-01 1.41105804e-07] -LogLike= 4799.953293366918 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000002e-01 4.52359732e-08] -LogLike= 4790.893496912846 #okay= 2000 #points= 2000
# theta= [4.00000008e-01 6.00000002e-01 4.52359732e-08] -LogLike= 4790.893517503886 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000012e-01 4.52359732e-08] -LogLike= 4790.893476384029 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000002e-01 5.52359732e-08] -LogLike= 4791.842511959781 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000002e-01 1.00000000e-09] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [4.00000008e-01 6.00000002e-01 1.00000000e-09] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000012e-01 1.00000000e-09] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000002e-01 1.10000000e-08] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000002e-01 4.52359421e-08] -LogLike= 4790.893493978751 #okay= 2000 #points= 2000
# theta= [4.00000008e-01 6.00000002e-01 4.52359421e-08] -LogLike= 4790.893514561827 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000012e-01 4.52359421e-08] -LogLike= 4790.893473451161 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000002e-01 5.52359421e-08] -LogLike= 4791.84250896171 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000002e-01 2.31179711e-08] -LogLike= 4788.843013086951 #okay= 2000 #points= 2000
# theta= [4.00000008e-01 6.00000002e-01 2.31179711e-08] -LogLike= 4788.843034206832 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000012e-01 2.31179711e-08] -LogLike= 4788.842992000375 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000002e-01 3.31179711e-08] -LogLike= 4789.748513688815 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000002e-01 8.52011016e-09] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [4.00000008e-01 6.00000002e-01 8.52011016e-09] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000012e-01 8.52011016e-09] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000002e-01 1.85201102e-08] -LogLike= 4788.432732935535 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000002e-01 2.31179648e-08] -LogLike= 4788.843012560477 #okay= 2000 #points= 2000
# theta= [4.00000008e-01 6.00000002e-01 2.31179648e-08] -LogLike= 4788.843033674588 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000012e-01 2.31179648e-08] -LogLike= 4788.842991474597 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000002e-01 3.31179648e-08] -LogLike= 4789.748513102819 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000002e-01 1.34833807e-08] -LogLike= 4787.992512916662 #okay= 2000 #points= 2000
# theta= [4.00000008e-01 6.00000002e-01 1.34833807e-08] -LogLike= 4787.9925342340075 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000012e-01 1.34833807e-08] -LogLike= 4787.992491595917 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000002e-01 2.34833807e-08] -LogLike= 4788.867332757756 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000002e-01 1.02076222e-08] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [4.00000008e-01 6.00000002e-01 1.02076222e-08] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000012e-01 1.02076222e-08] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000002e-01 2.02076222e-08] -LogLike= 4788.585219949502 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000002e-01 1.34833807e-08] -LogLike= 4787.992512916662 #okay= 2000 #points= 2000
# theta= [4.00000008e-01 6.00000002e-01 1.34833807e-08] -LogLike= 4787.9925342340075 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000012e-01 1.34833807e-08] -LogLike= 4787.992491595917 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000002e-01 2.34833807e-08] -LogLike= 4788.867332757756 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000002e-01 1.00000000e-09] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [4.00000008e-01 6.00000002e-01 1.00000000e-09] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000012e-01 1.00000000e-09] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000002e-01 1.10000000e-08] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000002e-01 1.34833784e-08] -LogLike= 4787.992512653385 #okay= 2000 #points= 2000
# theta= [4.00000008e-01 6.00000002e-01 1.34833784e-08] -LogLike= 4787.9925339830115 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000012e-01 1.34833784e-08] -LogLike= 4787.992491341755 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000002e-01 2.34833784e-08] -LogLike= 4788.867332559982 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000002e-01 7.24168922e-09] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [4.00000008e-01 6.00000002e-01 7.24168922e-09] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000012e-01 7.24168922e-09] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000002e-01 1.72416892e-08] -LogLike= 4788.317501956425 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000002e-01 1.34833777e-08] -LogLike= 4787.992512634256 #okay= 2000 #points= 2000
# theta= [4.00000008e-01 6.00000002e-01 1.34833777e-08] -LogLike= 4787.992533975693 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000012e-01 1.34833777e-08] -LogLike= 4787.992491333212 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000002e-01 2.34833777e-08] -LogLike= 4788.867332441691 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000002e-01 9.36386331e-09] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [4.00000008e-01 6.00000002e-01 9.36386331e-09] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000012e-01 9.36386331e-09] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000002e-01 1.93638633e-08] -LogLike= 4788.509123918883 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000002e-01 1.34833774e-08] -LogLike= 4787.992512655644 #okay= 2000 #points= 2000
# theta= [4.00000008e-01 6.00000002e-01 1.34833774e-08] -LogLike= 4787.9925339749125 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000012e-01 1.34833774e-08] -LogLike= 4787.992491336424 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000002e-01 2.34833774e-08] -LogLike= 4788.867332427286 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000002e-01 1.34833777e-08] -LogLike= 4787.992512634256 #okay= 2000 #points= 2000
# theta= [4.00000008e-01 6.00000002e-01 1.34833777e-08] -LogLike= 4787.992533975693 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000012e-01 1.34833777e-08] -LogLike= 4787.992491333212 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000002e-01 2.34833777e-08] -LogLike= 4788.867332441691 #okay= 2000 #points= 2000
# theta= (0.4000000980554502, 0.6000000019279957, 1.3483377726170445e-08) -LogLike= 4787.992725678875 #okay= 2000 #points= 2000
# theta= (0.3999998980554502, 0.6000000019279957, 1.3483377726170445e-08) -LogLike= 4787.992299480959 #okay= 2000 #points= 2000
# theta= (0.3999999980554502, 0.6000000019279957, 1.3483377726170445e-08) -LogLike= 4787.992512634256 #okay= 2000 #points= 2000
# theta= (0.3999999980554502, 0.6000001019279957, 1.3483377726170445e-08) -LogLike= 4787.992299645967 #okay= 2000 #points= 2000
# /Users/khudabukhsh.2/Work/DSA/numerical/wasiur/epidemiccore.py:1528: RuntimeWarning: invalid value encountered in sqrt
#   self.stda = 1/np.sqrt((aa1 - 2*aa3 + aa2)/d**2)
# theta= (0.3999999980554502, 0.5999999019279958, 1.3483377726170445e-08) -LogLike= 4787.992725514032 #okay= 2000 #points= 2000
# theta= (0.3999999980554502, 0.6000000019279957, 1.3483377726170445e-08) -LogLike= 4787.992512634256 #okay= 2000 #points= 2000
# theta= (0.3999999980554502, 0.6000000019279957, 1.4483377726170445e-08) -LogLike= 4788.078639731325 #okay= 2000 #points= 2000
# /Users/khudabukhsh.2/Work/DSA/numerical/wasiur/epidemiccore.py:1538: RuntimeWarning: invalid value encountered in sqrt
#   self.stdb = 1/np.sqrt((bb1 - 2*bb3 + bb2)/d**2)
# theta= (0.3999999980554502, 0.6000000019279957, 1.2483377726170444e-08) -LogLike= 4787.9303310668465 #okay= 2000 #points= 2000
# theta= (0.3999999980554502, 0.6000000019279957, 1.3483377726170445e-08) -LogLike= 4787.992512634256 #okay= 2000 #points= 2000
# Parameter    Name                                   MLE  Mean           StdErr
# -----------  ------------------------  ----------------  ------  -------------
# T            final time                    53
# a            beta+gamma+delta               0.4                  nan
# b            beta*mu                        0.6                  nan
# c            beta*mu*rho                    1.34834e-08            6.46231e-09
# R0           R-naught                       1.5
# rho          initial fraction I             2.24723e-08
# tau          epidemic size                  0.582812
# 1-S(T)       rescaling                      0.00288521
# n            #S+#I                          1.31082e+06
# kT           #I(T)                       3782
# sT           #S(T)                          1.30704e+06
# kinfty       #I(infty)                 763963
# sinfty       #S(infty)                 546860
# 1/rho        initial total population       4.44992e+07
# gamma        recovery rate
# offset       shift parameter
# \begin{tabular}{llrlr}
# \toprule
#  Parameter   & Name                     &              MLE & Mean   &        StdErr \\
# \midrule
#  T           & final time               &     53           &        &               \\
#  a           & beta+gamma+delta         &      0.4         &        & nan           \\
#  b           & beta*mu                  &      0.6         &        & nan           \\
#  c           & beta*mu*rho              &      1.34834e-08 &        &   6.46231e-09 \\
#  R0          & R-naught                 &      1.5         &        &               \\
#  rho         & initial fraction I       &      2.24723e-08 &        &               \\
#  tau         & epidemic size            &      0.582812    &        &               \\
#  1-S(T)      & rescaling                &      0.00288521  &        &               \\
#  n           & \#S+\#I                    &      1.31082e+06 &        &               \\
#  kT          & \#I(T)                    &   3782           &        &               \\
#  sT          & \#S(T)                    &      1.30704e+06 &        &               \\
#  kinfty      & \#I(infty)                & 763963           &        &               \\
#  sinfty      & \#S(infty)                & 546860           &        &               \\
#  1/rho       & initial total population &      4.44992e+07 &        &               \\
#  gamma       & recovery rate            &                  &        &               \\
#  offset      & shift parameter          &                  &        &               \\
# \bottomrule
# \end{tabular}

# %%
fi = epiT.Plot_FI_abc()
fname = 'FIusa'
fig_save(fi,Plot_Folder,fname)
#fi.savefig(os.path.join (Plot_Folder, fname),dpi=300)
#fi.savefig (os.path.join (Plot_Folder, fname + "." + 'pdf'), format='pdf')
## fig.savefig (os.path.join (Plot_Folder, fname + "." + 'svg'), format='svg')
#fi.savefig (os.path.join (Plot_Folder, fname + "." + 'eps'), format='eps', dpi=1000)
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
norescale = epiT.Plot_FI_integrand_ab(rescale=True)
fname = 'norescaleusa'
fig_save(norescale,Plot_Folder,fname)
# norescale.savefig(os.path.join (Plot_Folder, fname),dpi=300)
# norescale.savefig (os.path.join (Plot_Folder, fname + "." + 'pdf'), format='pdf')
# # fig.savefig (os.path.join (Plot_Folder, fname + "." + 'svg'), format='svg')
# norescale.savefig (os.path.join (Plot_Folder, fname + "." + 'eps'), format='eps', dpi=1000)
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
rescale = epiT.Plot_FI_integrand_ab(rescale=False)
fname = 'rescaleusa'
fig_save(rescale,Plot_Folder,fname)
# rescale.savefig(os.path.join (Plot_Folder, fname),dpi=300)
# rescale.savefig (os.path.join (Plot_Folder, fname + "." + 'pdf'), format='pdf')
# # fig.savefig (os.path.join (Plot_Folder, fname + "." + 'svg'), format='svg')
# rescale.savefig (os.path.join (Plot_Folder, fname + "." + 'eps'), format='eps', dpi=1000)
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fig_recovery = epiT.estimate_gamma(df_recovery=df_recovery,N=N,x0=(0.1,-5),bounds=[(1.0/25,1.0/5),(-10,0)],approach='offset')
# Out:
# naive-estimate -2.5696938566816043
# gamma= 0.1 offset= -5.0 -LOGLIKE= 5019.466666489158
# gamma= 0.10000001 offset= -5.0 -LOGLIKE= 5019.466665910173
# gamma= 0.1 offset= -4.99999999 -LOGLIKE= 5019.464693885784
# gamma= 0.2 offset= 0.0 -LOGLIKE= 1000000.0
# gamma= 0.20000001 offset= 0.0 -LOGLIKE= 1000000.0
# gamma= 0.2 offset= 1e-08 -LOGLIKE= 1000000.0
# gamma= 0.11104635398901568 offset= -4.447682300549217 -LOGLIKE= 5017.897201841812
# gamma= 0.11104636398901567 offset= -4.447682300549217 -LOGLIKE= 5017.897201380921
# gamma= 0.11104635398901568 offset= -4.447682290549217 -LOGLIKE= 5017.897201824582
# gamma= 0.10367668015635519 offset= -4.816165992182241 -LOGLIKE= 5018.8370382342855
# gamma= 0.10367669015635518 offset= -4.816165992182241 -LOGLIKE= 5018.8370376926005
# gamma= 0.10367668015635519 offset= -4.816165982182241 -LOGLIKE= 5018.837038215361
# gamma= 0.10122375632169409 offset= -4.938812183915297 -LOGLIKE= 5019.261643229445
# gamma= 0.10122376632169408 offset= -4.938812183915297 -LOGLIKE= 5019.261642663683
# gamma= 0.10122375632169409 offset= -4.938812173915297 -LOGLIKE= 5019.261643209053
# gamma= 0.10040731790757466 offset= -4.979634104621267 -LOGLIKE= 5019.397102752355
# gamma= 0.10040732790757466 offset= -4.979634104621267 -LOGLIKE= 5019.397102177717
# gamma= 0.10040731790757466 offset= -4.979634094621267 -LOGLIKE= 5019.397102736054
# gamma= 0.10013557286587242 offset= -4.993221356706379 -LOGLIKE= 5019.442616305897
# gamma= 0.10013558286587242 offset= -4.993221356706379 -LOGLIKE= 5019.442615728317
# gamma= 0.10013557286587242 offset= -4.993221346706379 -LOGLIKE= 5019.442616282631
# gamma= 0.10004512444339231 offset= -4.997743777830385 -LOGLIKE= 5019.457183955599
# gamma= 0.1000451344433923 offset= -4.997743777830385 -LOGLIKE= 5019.457183376973
# gamma= 0.10004512444339231 offset= -4.997743767830385 -LOGLIKE= 5019.457183937235
# gamma= 0.10001501946136514 offset= -4.999249026931744 -LOGLIKE= 5019.462188905691
# gamma= 0.10001502946136513 offset= -4.999249026931744 -LOGLIKE= 5019.462188326717
# gamma= 0.10001501946136514 offset= -4.999249016931744 -LOGLIKE= 5019.462188883001
# gamma= 0.10000499924157644 offset= -4.999750037921179 -LOGLIKE= 5019.463844506474
# gamma= 0.10000500924157643 offset= -4.999750037921179 -LOGLIKE= 5019.463843927386
# gamma= 0.10000499924157644 offset= -4.999750027921179 -LOGLIKE= 5019.463844477139
# gamma= 0.1000016640891876 offset= -4.99991679554062 -LOGLIKE= 5019.464410074346
# gamma= 0.1000016740891876 offset= -4.99991679554062 -LOGLIKE= 5019.46440949522
# gamma= 0.1000016640891876 offset= -4.99991678554062 -LOGLIKE= 5019.464410049441
# gamma= 0.10000055401206501 offset= -4.999972299396751 -LOGLIKE= 5019.464599491532
# gamma= 0.100000564012065 offset= -4.999972299396751 -LOGLIKE= 5019.464598912393
# gamma= 0.10000055401206501 offset= -4.999972289396751 -LOGLIKE= 5019.464599468066
# gamma= 0.10000018453175426 offset= -4.9999907734122875 -LOGLIKE= 5019.464662458899
# gamma= 0.10000019453175425 offset= -4.9999907734122875 -LOGLIKE= 5019.464661879756
# gamma= 0.10000018453175426 offset= -4.9999907634122875 -LOGLIKE= 5019.464662438824
# gamma= 0.10000018724468862 offset= -4.999990773264213 -LOGLIKE= 5019.464662301434
# gamma= 0.10000019724468862 offset= -4.999990773264213 -LOGLIKE= 5019.464661722292
# gamma= 0.10000018724468862 offset= -4.999990763264213 -LOGLIKE= 5019.464662280476
# gamma= 0.10000019809642607 offset= -4.999990772671915 -LOGLIKE= 5019.464661673345
# gamma= 0.10000020809642607 offset= -4.999990772671915 -LOGLIKE= 5019.464661094203
# gamma= 0.10000019809642607 offset= -4.999990762671915 -LOGLIKE= 5019.464661649119
# gamma= 0.10000024150337589 offset= -4.999990770302724 -LOGLIKE= 5019.464659154617
# gamma= 0.10000025150337588 offset= -4.999990770302724 -LOGLIKE= 5019.4646585754745
# gamma= 0.10000024150337589 offset= -4.999990760302724 -LOGLIKE= 5019.464659133138
# gamma= 0.10000041513117514 offset= -4.99999076082596 -LOGLIKE= 5019.464649075106
# gamma= 0.10000042513117513 offset= -4.99999076082596 -LOGLIKE= 5019.464648495965
# gamma= 0.10000041513117514 offset= -4.99999075082596 -LOGLIKE= 5019.464649055994
# gamma= 0.10000110964237213 offset= -4.999990722918903 -LOGLIKE= 5019.464608771853
# gamma= 0.10000111964237213 offset= -4.999990722918903 -LOGLIKE= 5019.464608192715
# gamma= 0.10000110964237213 offset= -4.999990712918903 -LOGLIKE= 5019.464608747996
# gamma= 0.10000388768716012 offset= -4.999990571290675 -LOGLIKE= 5019.464447545572
# gamma= 0.10000389768716011 offset= -4.999990571290675 -LOGLIKE= 5019.46444696645
# gamma= 0.10000388768716012 offset= -4.999990561290675 -LOGLIKE= 5019.464447520063
# gamma= 0.10001499986631207 offset= -4.999989964777762 -LOGLIKE= 5019.463802681799
# gamma= 0.10001500986631207 offset= -4.999989964777762 -LOGLIKE= 5019.46380210274
# gamma= 0.10001499986631207 offset= -4.999989954777762 -LOGLIKE= 5019.463802660328
# gamma= 0.10005944858291987 offset= -4.999987538726111 -LOGLIKE= 5019.461223926281
# gamma= 0.10005945858291987 offset= -4.999987538726111 -LOGLIKE= 5019.461223347468
# gamma= 0.10005944858291987 offset= -4.999987528726111 -LOGLIKE= 5019.461223902224
# gamma= 0.10023724344935109 offset= -4.999977834519506 -LOGLIKE= 5019.450919935758
# gamma= 0.10023725344935108 offset= -4.999977834519506 -LOGLIKE= 5019.450919357938
# gamma= 0.10023724344935109 offset= -4.999977824519506 -LOGLIKE= 5019.450919912198
# gamma= 0.10094842291507594 offset= -4.999939017693088 -LOGLIKE= 5019.409879877928
# gamma= 0.10094843291507594 offset= -4.999939017693088 -LOGLIKE= 5019.409879304053
# gamma= 0.10094842291507594 offset= -4.999939007693088 -LOGLIKE= 5019.409879851133
# gamma= 0.10379314077797536 offset= -4.999783750387416 -LOGLIKE= 5019.248499640098
# gamma= 0.10379315077797535 offset= -4.999783750387416 -LOGLIKE= 5019.24849908174
# gamma= 0.10379314077797536 offset= -4.999783740387416 -LOGLIKE= 5019.248499613644
# gamma= 0.11517201222957302 offset= -4.999162681164727 -LOGLIKE= 5018.645468492175
# gamma= 0.11517202222957301 offset= -4.999162681164727 -LOGLIKE= 5018.645467991779
# gamma= 0.11517201222957302 offset= -4.9991626711647275 -LOGLIKE= 5018.645468472082
# gamma= 0.2 offset= -4.994521096537741 -LOGLIKE= 1000000.0
# gamma= 0.20000001 offset= -4.994521096537741 -LOGLIKE= 1000000.0
# gamma= 0.2 offset= -4.994521086537741 -LOGLIKE= 1000000.0
# gamma= 0.11517207267702564 offset= -4.999162677857187 -LOGLIKE= 5018.6454654631525
# gamma= 0.11517208267702564 offset= -4.999162677857187 -LOGLIKE= 5018.645464962757
# gamma= 0.11517207267702564 offset= -4.999162667857187 -LOGLIKE= 5018.645465443653
# gamma= 0.1575860363385128 offset= -4.996841887197464 -LOGLIKE= 5016.898444545643
# gamma= 0.1575860463385128 offset= -4.996841887197464 -LOGLIKE= 5016.898444212697
# gamma= 0.1575860363385128 offset= -4.996841877197464 -LOGLIKE= 5016.8984445282795

# %%
fname = 'recoveryusa'
fig_save(fig_recovery,Plot_Folder,fname)

# %%
epiT.simulate_and_fit(N=N,n=n)
# Out:
# sample 1
# theta= [3.99999998e-01 6.00000002e-01 1.34833777e-08] -LogLike= 5203.867306089584 #okay= 2000 #points= 2000
# theta= [4.00000008e-01 6.00000002e-01 1.34833777e-08] -LogLike= 5203.867307153916 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000012e-01 1.34833777e-08] -LogLike= 5203.8673050226525 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000002e-01 2.34833777e-08] -LogLike= 5203.785068909116 #okay= 2000 #points= 2000
# theta= [0.1 1.  0.1] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [0.10000001 1.         0.1       ] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [0.1        1.00000001 0.1       ] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [0.1        1.         0.10000001] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [0.37075266 0.63899645 0.00974912] -LogLike= 18308.621544918755 #okay= 2000 #points= 2000
# theta= [0.37075267 0.63899645 0.00974912] -LogLike= 18308.621297314054 #okay= 2000 #points= 2000
# theta= [0.37075266 0.63899646 0.00974912] -LogLike= 18308.621908894504 #okay= 2000 #points= 2000
# theta= [0.37075266 0.63899645 0.00974913] -LogLike= 18308.62375798207 #okay= 2000 #points= 2000
# theta= [0.39248507 0.6100199  0.00250499] -LogLike= 13877.280076553205 #okay= 2000 #points= 2000
# theta= [0.39248508 0.6100199  0.00250499] -LogLike= 13877.27971057938 #okay= 2000 #points= 2000
# theta= [0.39248507 0.61001991 0.00250499] -LogLike= 13877.280504870218 #okay= 2000 #points= 2000
# theta= [0.39248507 0.6100199  0.002505  ] -LogLike= 13877.287029510875 #okay= 2000 #points= 2000
# theta= [3.98586368e-01 6.01884842e-01 4.71223356e-04] -LogLike= 10609.622853359466 #okay= 2000 #points= 2000
# theta= [3.98586378e-01 6.01884842e-01 4.71223356e-04] -LogLike= 10609.622435249898 #okay= 2000 #points= 2000
# theta= [3.98586368e-01 6.01884852e-01 4.71223356e-04] -LogLike= 10609.6233080651 #okay= 2000 #points= 2000
# theta= [3.98586368e-01 6.01884842e-01 4.71233356e-04] -LogLike= 10609.654454536982 #okay= 2000 #points= 2000
# theta= [3.99866259e-01 6.00178320e-01 4.45930466e-05] -LogLike= 7317.531949742301 #okay= 2000 #points= 2000
# theta= [3.99866269e-01 6.00178320e-01 4.45930466e-05] -LogLike= 7317.531580373532 #okay= 2000 #points= 2000
# theta= [3.99866259e-01 6.00178330e-01 4.45930466e-05] -LogLike= 7317.532336688379 #okay= 2000 #points= 2000
# theta= [3.99866259e-01 6.00178320e-01 4.46030466e-05] -LogLike= 7317.787763097828 #okay= 2000 #points= 2000
# theta= [3.99995740e-01 6.00005680e-01 1.43287806e-06] -LogLike= 5268.281056961406 #okay= 2000 #points= 2000
# theta= [3.99995750e-01 6.00005680e-01 1.43287806e-06] -LogLike= 5268.28103523592 #okay= 2000 #points= 2000
# theta= [3.99995740e-01 6.00005690e-01 1.43287806e-06] -LogLike= 5268.28107997041 #okay= 2000 #points= 2000
# theta= [3.99995740e-01 6.00005680e-01 1.44287806e-06] -LogLike= 5268.997014132496 #okay= 2000 #points= 2000
# theta= [3.99999776e-01 6.00000298e-01 8.75187478e-08] -LogLike= 5203.985799255863 #okay= 2000 #points= 2000
# theta= [3.99999786e-01 6.00000298e-01 8.75187478e-08] -LogLike= 5203.985801495559 #okay= 2000 #points= 2000
# theta= [3.99999776e-01 6.00000308e-01 8.75187478e-08] -LogLike= 5203.985797036077 #okay= 2000 #points= 2000
# theta= [3.99999776e-01 6.00000298e-01 9.75187478e-08] -LogLike= 5204.063917559212 #okay= 2000 #points= 2000
# theta= [3.99999919e-01 6.00000108e-01 3.99544779e-08] -LogLike= 5203.76518150118 #okay= 2000 #points= 2000
# theta= [3.99999929e-01 6.00000108e-01 3.99544779e-08] -LogLike= 5203.765183040703 #okay= 2000 #points= 2000
# theta= [3.99999919e-01 6.00000118e-01 3.99544779e-08] -LogLike= 5203.76517996112 #okay= 2000 #points= 2000
# theta= [3.99999919e-01 6.00000108e-01 4.99544779e-08] -LogLike= 5203.781248160876 #okay= 2000 #points= 2000
# theta= [3.99999932e-01 6.00000091e-01 3.56308304e-08] -LogLike= 5203.762430202721 #okay= 2000 #points= 2000
# theta= [3.99999942e-01 6.00000091e-01 3.56308304e-08] -LogLike= 5203.762431702154 #okay= 2000 #points= 2000
# theta= [3.99999932e-01 6.00000101e-01 3.56308304e-08] -LogLike= 5203.762428727513 #okay= 2000 #points= 2000
# theta= [3.99999932e-01 6.00000091e-01 4.56308304e-08] -LogLike= 5203.77276550619 #okay= 2000 #points= 2000
# theta= [3.99999955e-01 6.00000059e-01 2.78413599e-08] -LogLike= 5203.771130448383 #okay= 2000 #points= 2000
# theta= [3.99999965e-01 6.00000059e-01 2.78413599e-08] -LogLike= 5203.771131784615 #okay= 2000 #points= 2000
# theta= [3.99999955e-01 6.00000069e-01 2.78413599e-08] -LogLike= 5203.771129112261 #okay= 2000 #points= 2000
# theta= [3.99999955e-01 6.00000059e-01 3.78413599e-08] -LogLike= 5203.762735091665 #okay= 2000 #points= 2000
# theta= [3.99999935e-01 6.00000087e-01 3.46546135e-08] -LogLike= 5203.762968787981 #okay= 2000 #points= 2000
# theta= [3.99999945e-01 6.00000087e-01 3.46546135e-08] -LogLike= 5203.762970261416 #okay= 2000 #points= 2000
# theta= [3.99999935e-01 6.00000097e-01 3.46546135e-08] -LogLike= 5203.762967329376 #okay= 2000 #points= 2000
# theta= [3.99999935e-01 6.00000087e-01 4.46546135e-08] -LogLike= 5203.771482312319 #okay= 2000 #points= 2000
# theta= [3.99999932e-01 6.00000090e-01 3.55045548e-08] -LogLike= 5203.76246497249 #okay= 2000 #points= 2000
# theta= [3.99999942e-01 6.00000090e-01 3.55045548e-08] -LogLike= 5203.762466454534 #okay= 2000 #points= 2000
# theta= [3.99999932e-01 6.00000100e-01 3.55045548e-08] -LogLike= 5203.762463496436 #okay= 2000 #points= 2000
# theta= [3.99999932e-01 6.00000090e-01 4.55045548e-08] -LogLike= 5203.7725753944205 #okay= 2000 #points= 2000
# theta= [3.99999932e-01 6.00000090e-01 3.56110210e-08] -LogLike= 5203.762435116459 #okay= 2000 #points= 2000
# theta= [3.99999942e-01 6.00000090e-01 3.56110210e-08] -LogLike= 5203.762436592869 #okay= 2000 #points= 2000
# theta= [3.99999932e-01 6.00000100e-01 3.56110210e-08] -LogLike= 5203.762433641881 #okay= 2000 #points= 2000
# theta= [3.99999932e-01 6.00000090e-01 4.56110210e-08] -LogLike= 5203.772735457094 #okay= 2000 #points= 2000
# theta= [3.99999932e-01 6.00000091e-01 3.56276582e-08] -LogLike= 5203.762430988865 #okay= 2000 #points= 2000
# theta= [3.99999942e-01 6.00000091e-01 3.56276582e-08] -LogLike= 5203.762432464824 #okay= 2000 #points= 2000
# theta= [3.99999932e-01 6.00000101e-01 3.56276582e-08] -LogLike= 5203.762429511643 #okay= 2000 #points= 2000
# theta= [3.99999932e-01 6.00000091e-01 4.56276582e-08] -LogLike= 5203.772760692431 #okay= 2000 #points= 2000
# theta= [3.99999932e-01 6.00000091e-01 3.56303227e-08] -LogLike= 5203.762430331527 #okay= 2000 #points= 2000
# theta= [3.99999942e-01 6.00000091e-01 3.56303227e-08] -LogLike= 5203.7624318239805 #okay= 2000 #points= 2000
# theta= [3.99999932e-01 6.00000101e-01 3.56303227e-08] -LogLike= 5203.762428849528 #okay= 2000 #points= 2000
# theta= [3.99999932e-01 6.00000091e-01 4.56303227e-08] -LogLike= 5203.772764735056 #okay= 2000 #points= 2000
# theta= [3.99999932e-01 6.00000091e-01 3.56307496e-08] -LogLike= 5203.762430243907 #okay= 2000 #points= 2000
# theta= [3.99999942e-01 6.00000091e-01 3.56307496e-08] -LogLike= 5203.762431719455 #okay= 2000 #points= 2000
# theta= [3.99999932e-01 6.00000101e-01 3.56307496e-08] -LogLike= 5203.762428755407 #okay= 2000 #points= 2000
# theta= [3.99999932e-01 6.00000091e-01 4.56307496e-08] -LogLike= 5203.772765383156 #okay= 2000 #points= 2000
# theta= [3.99999932e-01 6.00000091e-01 3.56308200e-08] -LogLike= 5203.762430218078 #okay= 2000 #points= 2000
# theta= [3.99999942e-01 6.00000091e-01 3.56308200e-08] -LogLike= 5203.762431693599 #okay= 2000 #points= 2000
# theta= [3.99999932e-01 6.00000101e-01 3.56308200e-08] -LogLike= 5203.76242874287 #okay= 2000 #points= 2000
# theta= [3.99999932e-01 6.00000091e-01 4.56308200e-08] -LogLike= 5203.772765494841 #okay= 2000 #points= 2000
# theta= [3.99999932e-01 6.00000091e-01 3.56308296e-08] -LogLike= 5203.762430218874 #okay= 2000 #points= 2000
# theta= [3.99999942e-01 6.00000091e-01 3.56308296e-08] -LogLike= 5203.762431694872 #okay= 2000 #points= 2000
# theta= [3.99999932e-01 6.00000101e-01 3.56308296e-08] -LogLike= 5203.762428743789 #okay= 2000 #points= 2000
# theta= [3.99999932e-01 6.00000091e-01 4.56308296e-08] -LogLike= 5203.772765512101 #okay= 2000 #points= 2000
# theta= [3.99999932e-01 6.00000091e-01 3.56308303e-08] -LogLike= 5203.762430202533 #okay= 2000 #points= 2000
# theta= [3.99999942e-01 6.00000091e-01 3.56308303e-08] -LogLike= 5203.762431702133 #okay= 2000 #points= 2000
# theta= [3.99999932e-01 6.00000101e-01 3.56308303e-08] -LogLike= 5203.762428727498 #okay= 2000 #points= 2000
# theta= [3.99999932e-01 6.00000091e-01 4.56308303e-08] -LogLike= 5203.772765506145 #okay= 2000 #points= 2000
# theta= [3.99999932e-01 6.00000091e-01 3.56308303e-08] -LogLike= 5203.762430202352 #okay= 2000 #points= 2000
# theta= [3.99999942e-01 6.00000091e-01 3.56308303e-08] -LogLike= 5203.762431702198 #okay= 2000 #points= 2000
# theta= [3.99999932e-01 6.00000101e-01 3.56308303e-08] -LogLike= 5203.762428727716 #okay= 2000 #points= 2000
# theta= [3.99999932e-01 6.00000091e-01 4.56308303e-08] -LogLike= 5203.772765506115 #okay= 2000 #points= 2000
# theta= [3.99999932e-01 6.00000091e-01 3.56308300e-08] -LogLike= 5203.762430223361 #okay= 2000 #points= 2000
# theta= [3.99999942e-01 6.00000091e-01 3.56308300e-08] -LogLike= 5203.762431697502 #okay= 2000 #points= 2000
# theta= [3.99999932e-01 6.00000101e-01 3.56308300e-08] -LogLike= 5203.762428724621 #okay= 2000 #points= 2000
# theta= [3.99999932e-01 6.00000091e-01 4.56308300e-08] -LogLike= 5203.772765515513 #okay= 2000 #points= 2000
# theta= [3.99999932e-01 6.00000091e-01 3.56308303e-08] -LogLike= 5203.762430202419 #okay= 2000 #points= 2000
# theta= [3.99999942e-01 6.00000091e-01 3.56308303e-08] -LogLike= 5203.762431702176 #okay= 2000 #points= 2000
# theta= [3.99999932e-01 6.00000101e-01 3.56308303e-08] -LogLike= 5203.76242872774 #okay= 2000 #points= 2000
# theta= [3.99999932e-01 6.00000091e-01 4.56308303e-08] -LogLike= 5203.772765506167 #okay= 2000 #points= 2000
# theta= [3.99999932e-01 6.00000091e-01 3.56308303e-08] -LogLike= 5203.762430202352 #okay= 2000 #points= 2000
# theta= [3.99999942e-01 6.00000091e-01 3.56308303e-08] -LogLike= 5203.762431702198 #okay= 2000 #points= 2000
# theta= [3.99999932e-01 6.00000101e-01 3.56308303e-08] -LogLike= 5203.762428727716 #okay= 2000 #points= 2000
# theta= [3.99999932e-01 6.00000091e-01 4.56308303e-08] -LogLike= 5203.772765506115 #okay= 2000 #points= 2000
# theta= (0.4000000316044206, 0.6000000905292379, 3.563083034016133e-08) -LogLike= 5203.762445008056 #okay= 2000 #points= 2000
# theta= (0.3999998316044206, 0.6000000905292379, 3.563083034016133e-08) -LogLike= 5203.7624154213145 #okay= 2000 #points= 2000
# theta= (0.3999999316044206, 0.6000000905292379, 3.563083034016133e-08) -LogLike= 5203.762430202352 #okay= 2000 #points= 2000
# theta= (0.3999999316044206, 0.6000001905292378, 3.563083034016133e-08) -LogLike= 5203.762415433089 #okay= 2000 #points= 2000
# theta= (0.3999999316044206, 0.5999999905292379, 3.563083034016133e-08) -LogLike= 5203.762444996334 #okay= 2000 #points= 2000
# theta= (0.3999999316044206, 0.6000000905292379, 3.563083034016133e-08) -LogLike= 5203.762430202352 #okay= 2000 #points= 2000
# theta= (0.3999999316044206, 0.6000000905292379, 3.6630830340161335e-08) -LogLike= 5203.762392025767 #okay= 2000 #points= 2000
# theta= (0.3999999316044206, 0.6000000905292379, 3.463083034016133e-08) -LogLike= 5203.762983200064 #okay= 2000 #points= 2000
# theta= (0.3999999316044206, 0.6000000905292379, 3.563083034016133e-08) -LogLike= 5203.762430202352 #okay= 2000 #points= 2000
# Parameter    Name                                   MLE  Mean         StdErr
# -----------  ------------------------  ----------------  ------  -----------
# T            final time                    53
# a            beta+gamma+delta               0.4                  0.00063673
# b            beta*mu                        0.6                  0.00063605
# c            beta*mu*rho                    3.56308e-08          4.40729e-08
# R0           R-naught                       1.5
# rho          initial fraction I             5.93847e-08
# tau          epidemic size                  0.582812
# 1-S(T)       rescaling                      0.00744919
# n            #S+#I                     507706
# kT           #I(T)                       3782
# sT           #S(T)                     503924
# kinfty       #I(infty)                 295897
# sinfty       #S(infty)                 211809
# 1/rho        initial total population       1.68394e+07
# gamma        recovery rate
# offset       shift parameter
# \begin{tabular}{llrlr}
# \toprule
#  Parameter   & Name                     &              MLE & Mean   &      StdErr \\
# \midrule
#  T           & final time               &     53           &        &             \\
#  a           & beta+gamma+delta         &      0.4         &        & 0.00063673  \\
#  b           & beta*mu                  &      0.6         &        & 0.00063605  \\
#  c           & beta*mu*rho              &      3.56308e-08 &        & 4.40729e-08 \\
#  R0          & R-naught                 &      1.5         &        &             \\
#  rho         & initial fraction I       &      5.93847e-08 &        &             \\
#  tau         & epidemic size            &      0.582812    &        &             \\
#  1-S(T)      & rescaling                &      0.00744919  &        &             \\
#  n           & \#S+\#I                    & 507706           &        &             \\
#  kT          & \#I(T)                    &   3782           &        &             \\
#  sT          & \#S(T)                    & 503924           &        &             \\
#  kinfty      & \#I(infty)                & 295897           &        &             \\
#  sinfty      & \#S(infty)                & 211809           &        &             \\
#  1/rho       & initial total population &      1.68394e+07 &        &             \\
#  gamma       & recovery rate            &                  &        &             \\
#  offset      & shift parameter          &                  &        &             \\
# \bottomrule
# \end{tabular}
# sample 2
# theta= [3.99999998e-01 6.00000002e-01 1.34833777e-08] -LogLike= 5286.085106700686 #okay= 2000 #points= 2000
# theta= [4.00000008e-01 6.00000002e-01 1.34833777e-08] -LogLike= 5286.085103704424 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000012e-01 1.34833777e-08] -LogLike= 5286.085109697643 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000002e-01 2.34833777e-08] -LogLike= 5285.913363677992 #okay= 2000 #points= 2000
# theta= [1.  0.1 0.1] -LogLike= 1000000.0 #okay= 4 #points= 2000
# theta= [1.00000001 0.1        0.1       ] -LogLike= 1000000.0 #okay= 4 #points= 2000
# theta= [1.         0.10000001 0.1       ] -LogLike= 1000000.0 #okay= 4 #points= 2000
# theta= [1.         0.1        0.10000001] -LogLike= 1000000.0 #okay= 4 #points= 2000
# theta= [0.49267185 0.52277346 0.01544532] -LogLike= 14071.933629699182 #okay= 2000 #points= 2000
# theta= [0.49267186 0.52277346 0.01544532] -LogLike= 14071.933709351188 #okay= 2000 #points= 2000
# theta= [0.49267185 0.52277347 0.01544532] -LogLike= 14071.933644307337 #okay= 2000 #points= 2000
# theta= [0.49267185 0.52277346 0.01544533] -LogLike= 14071.936474847102 #okay= 2000 #points= 2000
# theta= [0.42923798 0.57563501 0.00487301] -LogLike= 12437.762802093206 #okay= 2000 #points= 2000
# theta= [0.42923799 0.57563501 0.00487301] -LogLike= 12437.762481585514 #okay= 2000 #points= 2000
# theta= [0.42923798 0.57563502 0.00487301] -LogLike= 12437.763180278782 #okay= 2000 #points= 2000
# theta= [0.42923798 0.57563501 0.00487302] -LogLike= 12437.76760373436 #okay= 2000 #points= 2000
# theta= [0.40834555 0.59304538 0.00139094] -LogLike= 11463.453573413664 #okay= 2000 #points= 2000
# theta= [0.40834556 0.59304538 0.00139094] -LogLike= 11463.453182251069 #okay= 2000 #points= 2000
# theta= [0.40834555 0.59304539 0.00139094] -LogLike= 11463.454008218818 #okay= 2000 #points= 2000
# theta= [0.40834555 0.59304538 0.00139095] -LogLike= 11463.46564669677 #okay= 2000 #points= 2000
# theta= [4.01864512e-01 5.98446241e-01 3.10765702e-04] -LogLike= 9657.28422777741 #okay= 2000 #points= 2000
# theta= [4.01864522e-01 5.98446241e-01 3.10765702e-04] -LogLike= 9657.283814228706 #okay= 2000 #points= 2000
# theta= [4.01864512e-01 5.98446251e-01 3.10765702e-04] -LogLike= 9657.284672115331 #okay= 2000 #points= 2000
# theta= [4.01864512e-01 5.98446241e-01 3.10775702e-04] -LogLike= 9657.330237071408 #okay= 2000 #points= 2000
# theta= [4.00249613e-01 5.99791989e-01 4.16159757e-05] -LogLike= 7205.648510192469 #okay= 2000 #points= 2000
# theta= [4.00249623e-01 5.99791989e-01 4.16159757e-05] -LogLike= 7205.648157425918 #okay= 2000 #points= 2000
# theta= [4.00249613e-01 5.99791999e-01 4.16159757e-05] -LogLike= 7205.648879546159 #okay= 2000 #points= 2000
# theta= [4.00249613e-01 5.99791989e-01 4.16259757e-05] -LogLike= 7205.910019504707 #okay= 2000 #points= 2000
# theta= [4.00015391e-01 5.99987175e-01 2.57893333e-06] -LogLike= 5424.129845177585 #okay= 2000 #points= 2000
# theta= [4.00015401e-01 5.99987175e-01 2.57893333e-06] -LogLike= 5424.129788088004 #okay= 2000 #points= 2000
# theta= [4.00015391e-01 5.99987185e-01 2.57893333e-06] -LogLike= 5424.1299048059955 #okay= 2000 #points= 2000
# theta= [4.00015391e-01 5.99987175e-01 2.58893333e-06] -LogLike= 5424.907388093266 #okay= 2000 #points= 2000
# theta= [4.00001171e-01 5.99999024e-01 2.08980855e-07] -LogLike= 5286.298165811861 #okay= 2000 #points= 2000
# theta= [4.00001181e-01 5.99999024e-01 2.08980855e-07] -LogLike= 5286.298165394083 #okay= 2000 #points= 2000
# theta= [4.00001171e-01 5.99999034e-01 2.08980855e-07] -LogLike= 5286.298166220837 #okay= 2000 #points= 2000
# theta= [4.00001171e-01 5.99999024e-01 2.18980855e-07] -LogLike= 5286.4163213228685 #okay= 2000 #points= 2000
# theta= [4.00000473e-01 5.99999607e-01 9.25608759e-08] -LogLike= 5285.598917700484 #okay= 2000 #points= 2000
# theta= [4.00000483e-01 5.99999607e-01 9.25608759e-08] -LogLike= 5285.598916180231 #okay= 2000 #points= 2000
# theta= [4.00000473e-01 5.99999617e-01 9.25608759e-08] -LogLike= 5285.598919226611 #okay= 2000 #points= 2000
# theta= [4.00000473e-01 5.99999607e-01 1.02560876e-07] -LogLike= 5285.608293714063 #okay= 2000 #points= 2000
# theta= [4.00000448e-01 5.99999627e-01 8.84749395e-08] -LogLike= 5285.59848002007 #okay= 2000 #points= 2000
# theta= [4.00000458e-01 5.99999627e-01 8.84749395e-08] -LogLike= 5285.5984784340035 #okay= 2000 #points= 2000
# theta= [4.00000448e-01 5.99999637e-01 8.84749395e-08] -LogLike= 5285.598481598825 #okay= 2000 #points= 2000
# theta= [4.00000448e-01 5.99999627e-01 9.84749395e-08] -LogLike= 5285.603009934015 #okay= 2000 #points= 2000
# theta= [4.00000425e-01 5.99999646e-01 8.46707565e-08] -LogLike= 5285.599796019452 #okay= 2000 #points= 2000
# theta= [4.00000435e-01 5.99999646e-01 8.46707565e-08] -LogLike= 5285.599794373275 #okay= 2000 #points= 2000
# theta= [4.00000425e-01 5.99999656e-01 8.46707565e-08] -LogLike= 5285.599797659349 #okay= 2000 #points= 2000
# theta= [4.00000425e-01 5.99999646e-01 9.46707565e-08] -LogLike= 5285.599972722191 #okay= 2000 #points= 2000
# theta= [4.00000445e-01 5.99999629e-01 8.79786112e-08] -LogLike= 5285.5985774382725 #okay= 2000 #points= 2000
# theta= [4.00000455e-01 5.99999629e-01 8.79786112e-08] -LogLike= 5285.598575856042 #okay= 2000 #points= 2000
# theta= [4.00000445e-01 5.99999639e-01 8.79786112e-08] -LogLike= 5285.598579034346 #okay= 2000 #points= 2000
# theta= [4.00000445e-01 5.99999629e-01 9.79786112e-08] -LogLike= 5285.602539534369 #okay= 2000 #points= 2000
# theta= [4.00000448e-01 5.99999627e-01 8.84061716e-08] -LogLike= 5285.598486243754 #okay= 2000 #points= 2000
# theta= [4.00000458e-01 5.99999627e-01 8.84061716e-08] -LogLike= 5285.598484656546 #okay= 2000 #points= 2000
# theta= [4.00000448e-01 5.99999637e-01 8.84061716e-08] -LogLike= 5285.598487835364 #okay= 2000 #points= 2000
# theta= [4.00000448e-01 5.99999627e-01 9.84061716e-08] -LogLike= 5285.602937403367 #okay= 2000 #points= 2000
# theta= [4.00000448e-01 5.99999627e-01 8.84634220e-08] -LogLike= 5285.598481023626 #okay= 2000 #points= 2000
# theta= [4.00000458e-01 5.99999627e-01 8.84634220e-08] -LogLike= 5285.59847943936 #okay= 2000 #points= 2000
# theta= [4.00000448e-01 5.99999637e-01 8.84634220e-08] -LogLike= 5285.598482604525 #okay= 2000 #points= 2000
# theta= [4.00000448e-01 5.99999627e-01 9.84634220e-08] -LogLike= 5285.602997753445 #okay= 2000 #points= 2000
# theta= [4.00000448e-01 5.99999627e-01 8.84730042e-08] -LogLike= 5285.598480183269 #okay= 2000 #points= 2000
# theta= [4.00000458e-01 5.99999627e-01 8.84730042e-08] -LogLike= 5285.598478602984 #okay= 2000 #points= 2000
# theta= [4.00000448e-01 5.99999637e-01 8.84730042e-08] -LogLike= 5285.59848175944 #okay= 2000 #points= 2000
# theta= [4.00000448e-01 5.99999627e-01 9.84730042e-08] -LogLike= 5285.603007893373 #okay= 2000 #points= 2000
# theta= [4.00000448e-01 5.99999627e-01 8.84746124e-08] -LogLike= 5285.598480045246 #okay= 2000 #points= 2000
# theta= [4.00000458e-01 5.99999627e-01 8.84746124e-08] -LogLike= 5285.598478459483 #okay= 2000 #points= 2000
# theta= [4.00000448e-01 5.99999637e-01 8.84746124e-08] -LogLike= 5285.598481621977 #okay= 2000 #points= 2000
# theta= [4.00000448e-01 5.99999627e-01 9.84746124e-08] -LogLike= 5285.6030095931865 #okay= 2000 #points= 2000
# theta= [4.00000448e-01 5.99999627e-01 8.84748833e-08] -LogLike= 5285.598480012078 #okay= 2000 #points= 2000
# theta= [4.00000458e-01 5.99999627e-01 8.84748833e-08] -LogLike= 5285.59847844205 #okay= 2000 #points= 2000
# theta= [4.00000448e-01 5.99999637e-01 8.84748833e-08] -LogLike= 5285.598481600623 #okay= 2000 #points= 2000
# theta= [4.00000448e-01 5.99999627e-01 9.84748833e-08] -LogLike= 5285.603009869199 #okay= 2000 #points= 2000
# theta= [4.00000448e-01 5.99999627e-01 8.84747045e-08] -LogLike= 5285.598480040249 #okay= 2000 #points= 2000
# theta= [4.00000458e-01 5.99999627e-01 8.84747045e-08] -LogLike= 5285.598478455174 #okay= 2000 #points= 2000
# theta= [4.00000448e-01 5.99999637e-01 8.84747045e-08] -LogLike= 5285.598481615416 #okay= 2000 #points= 2000
# theta= [4.00000448e-01 5.99999627e-01 9.84747045e-08] -LogLike= 5285.603009689255 #okay= 2000 #points= 2000
# theta= [4.00000448e-01 5.99999627e-01 8.84748575e-08] -LogLike= 5285.598480026484 #okay= 2000 #points= 2000
# theta= [4.00000458e-01 5.99999627e-01 8.84748575e-08] -LogLike= 5285.598478439438 #okay= 2000 #points= 2000
# theta= [4.00000448e-01 5.99999637e-01 8.84748575e-08] -LogLike= 5285.598481602326 #okay= 2000 #points= 2000
# theta= [4.00000448e-01 5.99999627e-01 9.84748575e-08] -LogLike= 5285.603009842499 #okay= 2000 #points= 2000
# theta= [4.00000448e-01 5.99999627e-01 8.84748812e-08] -LogLike= 5285.598480016183 #okay= 2000 #points= 2000
# theta= [4.00000458e-01 5.99999627e-01 8.84748812e-08] -LogLike= 5285.598478444166 #okay= 2000 #points= 2000
# theta= [4.00000448e-01 5.99999637e-01 8.84748812e-08] -LogLike= 5285.598481602732 #okay= 2000 #points= 2000
# theta= [4.00000448e-01 5.99999627e-01 9.84748812e-08] -LogLike= 5285.603009874982 #okay= 2000 #points= 2000
# theta= [4.00000448e-01 5.99999627e-01 8.84748833e-08] -LogLike= 5285.598480012078 #okay= 2000 #points= 2000
# theta= [4.00000458e-01 5.99999627e-01 8.84748833e-08] -LogLike= 5285.59847844205 #okay= 2000 #points= 2000
# theta= [4.00000448e-01 5.99999637e-01 8.84748833e-08] -LogLike= 5285.598481600623 #okay= 2000 #points= 2000
# theta= [4.00000448e-01 5.99999627e-01 9.84748833e-08] -LogLike= 5285.603009869199 #okay= 2000 #points= 2000
# theta= (0.4000005480513278, 0.5999996269313123, 8.847488327668337e-08) -LogLike= 5285.598464184313 #okay= 2000 #points= 2000
# theta= (0.4000003480513278, 0.5999996269313123, 8.847488327668337e-08) -LogLike= 5285.598495856383 #okay= 2000 #points= 2000
# theta= (0.4000004480513278, 0.5999996269313123, 8.847488327668337e-08) -LogLike= 5285.598480012078 #okay= 2000 #points= 2000
# theta= (0.4000004480513278, 0.5999997269313122, 8.847488327668337e-08) -LogLike= 5285.5984958606705 #okay= 2000 #points= 2000
# theta= (0.4000004480513278, 0.5999995269313123, 8.847488327668337e-08) -LogLike= 5285.598464180102 #okay= 2000 #points= 2000
# theta= (0.4000004480513278, 0.5999996269313123, 8.847488327668337e-08) -LogLike= 5285.598480012078 #okay= 2000 #points= 2000
# theta= (0.4000004480513278, 0.5999996269313123, 8.947488327668336e-08) -LogLike= 5285.598412230164 #okay= 2000 #points= 2000
# theta= (0.4000004480513278, 0.5999996269313123, 8.747488327668337e-08) -LogLike= 5285.598659523821 #okay= 2000 #points= 2000
# theta= (0.4000004480513278, 0.5999996269313123, 8.847488327668337e-08) -LogLike= 5285.598480012078 #okay= 2000 #points= 2000
# Parameter    Name                                   MLE  Mean         StdErr
# -----------  ------------------------  ----------------  ------  -----------
# T            final time                    53
# a            beta+gamma+delta               0.4                  0.000777534
# b            beta*mu                        0.6                  0.000775745
# c            beta*mu*rho                    8.84749e-08          9.46053e-08
# R0           R-naught                       1.5
# rho          initial fraction I             1.47458e-07
# tau          epidemic size                  0.58281
# 1-S(T)       rescaling                      0.0178177
# n            #S+#I                     212261
# kT           #I(T)                       3782
# sT           #S(T)                     208479
# kinfty       #I(infty)                 123708
# sinfty       #S(infty)                  88553.2
# 1/rho        initial total population       6.78158e+06
# gamma        recovery rate
# offset       shift parameter
# \begin{tabular}{llrlr}
# \toprule
#  Parameter   & Name                     &              MLE & Mean   &      StdErr \\
# \midrule
#  T           & final time               &     53           &        &             \\
#  a           & beta+gamma+delta         &      0.4         &        & 0.000777534 \\
#  b           & beta*mu                  &      0.6         &        & 0.000775745 \\
#  c           & beta*mu*rho              &      8.84749e-08 &        & 9.46053e-08 \\
#  R0          & R-naught                 &      1.5         &        &             \\
#  rho         & initial fraction I       &      1.47458e-07 &        &             \\
#  tau         & epidemic size            &      0.58281     &        &             \\
#  1-S(T)      & rescaling                &      0.0178177   &        &             \\
#  n           & \#S+\#I                    & 212261           &        &             \\
#  kT          & \#I(T)                    &   3782           &        &             \\
#  sT          & \#S(T)                    & 208479           &        &             \\
#  kinfty      & \#I(infty)                & 123708           &        &             \\
#  sinfty      & \#S(infty)                &  88553.2         &        &             \\
#  1/rho       & initial total population &      6.78158e+06 &        &             \\
#  gamma       & recovery rate            &                  &        &             \\
#  offset      & shift parameter          &                  &        &             \\
# \bottomrule
# \end{tabular}
# sample 3
# theta= [3.99999998e-01 6.00000002e-01 1.34833777e-08] -LogLike= 5265.407852659878 #okay= 2000 #points= 2000
# theta= [4.00000008e-01 6.00000002e-01 1.34833777e-08] -LogLike= 5265.407850689421 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000012e-01 1.34833777e-08] -LogLike= 5265.4078546261835 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000002e-01 2.34833777e-08] -LogLike= 5265.237915513202 #okay= 2000 #points= 2000
# theta= [1.  0.1 0.1] -LogLike= 1000000.0 #okay= 3 #points= 2000
# theta= [1.00000001 0.1        0.1       ] -LogLike= 1000000.0 #okay= 3 #points= 2000
# theta= [1.         0.10000001 0.1       ] -LogLike= 1000000.0 #okay= 3 #points= 2000
# theta= [1.         0.1        0.10000001] -LogLike= 1000000.0 #okay= 3 #points= 2000
# theta= [0.49214213 0.5232149  0.01535703] -LogLike= 14055.697095378273 #okay= 2000 #points= 2000
# theta= [0.49214214 0.5232149  0.01535703] -LogLike= 14055.697170602065 #okay= 2000 #points= 2000
# theta= [0.49214213 0.52321491 0.01535703] -LogLike= 14055.697113556334 #okay= 2000 #points= 2000
# theta= [0.49214213 0.5232149  0.01535704] -LogLike= 14055.699952364834 #okay= 2000 #points= 2000
# theta= [0.42904015 0.57579987 0.00484004] -LogLike= 12449.18184439125 #okay= 2000 #points= 2000
# theta= [0.42904016 0.57579987 0.00484004] -LogLike= 12449.181522398112 #okay= 2000 #points= 2000
# theta= [0.42904015 0.57579988 0.00484004] -LogLike= 12449.18222403905 #okay= 2000 #points= 2000
# theta= [0.42904015 0.57579987 0.00484005] -LogLike= 12449.186667715825 #okay= 2000 #points= 2000
# theta= [0.40826268 0.59311443 0.00137713] -LogLike= 11469.73430994451 #okay= 2000 #points= 2000
# theta= [0.40826269 0.59311443 0.00137713] -LogLike= 11469.733917576872 #okay= 2000 #points= 2000
# theta= [0.40826268 0.59311444 0.00137713] -LogLike= 11469.734745951093 #okay= 2000 #points= 2000
# theta= [0.40826268 0.59311443 0.00137714] -LogLike= 11469.746491812815 #okay= 2000 #points= 2000
# theta= [4.01830736e-01 5.98474387e-01 3.05136392e-04] -LogLike= 9649.136472322723 #okay= 2000 #points= 2000
# theta= [4.01830746e-01 5.98474387e-01 3.05136392e-04] -LogLike= 9649.13605704162 #okay= 2000 #points= 2000
# theta= [4.01830736e-01 5.98474397e-01 3.05136392e-04] -LogLike= 9649.136918338978 #okay= 2000 #points= 2000
# theta= [4.01830736e-01 5.98474387e-01 3.05146392e-04] -LogLike= 9649.183374646567 #okay= 2000 #points= 2000
# theta= [4.00240469e-01 5.99799609e-01 4.00919746e-05] -LogLike= 7168.290081784436 #okay= 2000 #points= 2000
# theta= [4.00240479e-01 5.99799609e-01 4.00919746e-05] -LogLike= 7168.289728969535 #okay= 2000 #points= 2000
# theta= [4.00240469e-01 5.99799619e-01 4.00919746e-05] -LogLike= 7168.290451075962 #okay= 2000 #points= 2000
# theta= [4.00240469e-01 5.99799609e-01 4.01019746e-05] -LogLike= 7168.561358315424 #okay= 2000 #points= 2000
# theta= [4.00014384e-01 5.99988014e-01 2.41112859e-06] -LogLike= 5394.786779772986 #okay= 2000 #points= 2000
# theta= [4.00014394e-01 5.99988014e-01 2.41112859e-06] -LogLike= 5394.786727346178 #okay= 2000 #points= 2000
# theta= [4.00014384e-01 5.99988024e-01 2.41112859e-06] -LogLike= 5394.786834593443 #okay= 2000 #points= 2000
# theta= [4.00014384e-01 5.99988014e-01 2.42112859e-06] -LogLike= 5395.5703152138085 #okay= 2000 #points= 2000
# theta= [4.00001087e-01 5.99999095e-01 1.94938601e-07] -LogLike= 5265.814695560756 #okay= 2000 #points= 2000
# theta= [4.00001097e-01 5.99999095e-01 1.94938601e-07] -LogLike= 5265.814695966013 #okay= 2000 #points= 2000
# theta= [4.00001087e-01 5.99999105e-01 1.94938601e-07] -LogLike= 5265.814695217072 #okay= 2000 #points= 2000
# theta= [4.00001087e-01 5.99999095e-01 2.04938601e-07] -LogLike= 5265.941127519061 #okay= 2000 #points= 2000
# theta= [4.00000396e-01 5.99999670e-01 7.98785133e-08] -LogLike= 5265.046798660068 #okay= 2000 #points= 2000
# theta= [4.00000406e-01 5.99999670e-01 7.98785133e-08] -LogLike= 5265.046797907845 #okay= 2000 #points= 2000
# theta= [4.00000396e-01 5.99999680e-01 7.98785133e-08] -LogLike= 5265.046799415612 #okay= 2000 #points= 2000
# theta= [4.00000396e-01 5.99999670e-01 8.98785133e-08] -LogLike= 5265.0654036474525 #okay= 2000 #points= 2000
# theta= [4.00000357e-01 5.99999703e-01 7.33301482e-08] -LogLike= 5265.041883711481 #okay= 2000 #points= 2000
# theta= [4.00000367e-01 5.99999703e-01 7.33301482e-08] -LogLike= 5265.041882858196 #okay= 2000 #points= 2000
# theta= [4.00000357e-01 5.99999713e-01 7.33301482e-08] -LogLike= 5265.041884576428 #okay= 2000 #points= 2000
# theta= [4.00000357e-01 5.99999703e-01 8.33301482e-08] -LogLike= 5265.051081428912 #okay= 2000 #points= 2000
# theta= [4.00000319e-01 5.99999735e-01 6.69350054e-08] -LogLike= 5265.042091619942 #okay= 2000 #points= 2000
# theta= [4.00000329e-01 5.99999735e-01 6.69350054e-08] -LogLike= 5265.042090656071 #okay= 2000 #points= 2000
# theta= [4.00000319e-01 5.99999745e-01 6.69350054e-08] -LogLike= 5265.042092642429 #okay= 2000 #points= 2000
# theta= [4.00000319e-01 5.99999735e-01 7.69350054e-08] -LogLike= 5265.043946444796 #okay= 2000 #points= 2000
# theta= [4.00000346e-01 5.99999712e-01 7.15207902e-08] -LogLike= 5265.041404582829 #okay= 2000 #points= 2000
# theta= [4.00000356e-01 5.99999712e-01 7.15207902e-08] -LogLike= 5265.041403668096 #okay= 2000 #points= 2000
# theta= [4.00000346e-01 5.99999722e-01 7.15207902e-08] -LogLike= 5265.04140545976 #okay= 2000 #points= 2000
# theta= [4.00000346e-01 5.99999712e-01 8.15207902e-08] -LogLike= 5265.048858716578 #okay= 2000 #points= 2000
# theta= [4.00000300e-01 5.99999750e-01 6.37975798e-08] -LogLike= 5265.050436761672 #okay= 2000 #points= 2000
# theta= [4.00000310e-01 5.99999750e-01 6.37975798e-08] -LogLike= 5265.050435717894 #okay= 2000 #points= 2000
# theta= [4.00000300e-01 5.99999760e-01 6.37975798e-08] -LogLike= 5265.050437773341 #okay= 2000 #points= 2000
# theta= [4.00000300e-01 5.99999750e-01 7.37975798e-08] -LogLike= 5265.042070178411 #okay= 2000 #points= 2000
# theta= [4.00000342e-01 5.99999715e-01 7.07706827e-08] -LogLike= 5265.0413041532165 #okay= 2000 #points= 2000
# theta= [4.00000352e-01 5.99999715e-01 7.07706827e-08] -LogLike= 5265.041303264934 #okay= 2000 #points= 2000
# theta= [4.00000342e-01 5.99999725e-01 7.07706827e-08] -LogLike= 5265.041305054499 #okay= 2000 #points= 2000
# theta= [4.00000342e-01 5.99999715e-01 8.07706827e-08] -LogLike= 5265.0478898168 #okay= 2000 #points= 2000
# theta= [4.00000308e-01 5.99999744e-01 6.50907972e-08] -LogLike= 5265.050248602171 #okay= 2000 #points= 2000
# theta= [4.00000318e-01 5.99999744e-01 6.50907972e-08] -LogLike= 5265.050247621299 #okay= 2000 #points= 2000
# theta= [4.00000308e-01 5.99999754e-01 6.50907972e-08] -LogLike= 5265.050249588245 #okay= 2000 #points= 2000
# theta= [4.00000308e-01 5.99999744e-01 7.50907972e-08] -LogLike= 5265.04269327031 #okay= 2000 #points= 2000
# theta= [4.00000340e-01 5.99999717e-01 7.03957397e-08] -LogLike= 5265.041271328973 #okay= 2000 #points= 2000
# theta= [4.00000350e-01 5.99999717e-01 7.03957397e-08] -LogLike= 5265.041270434655 #okay= 2000 #points= 2000
# theta= [4.00000340e-01 5.99999727e-01 7.03957397e-08] -LogLike= 5265.041272223761 #okay= 2000 #points= 2000
# theta= [4.00000340e-01 5.99999717e-01 8.03957397e-08] -LogLike= 5265.04741992752 #okay= 2000 #points= 2000
# theta= [4.00000319e-01 5.99999735e-01 6.68944777e-08] -LogLike= 5265.042106587564 #okay= 2000 #points= 2000
# theta= [4.00000329e-01 5.99999735e-01 6.68944777e-08] -LogLike= 5265.042105618183 #okay= 2000 #points= 2000
# theta= [4.00000319e-01 5.99999745e-01 6.68944777e-08] -LogLike= 5265.042107529875 #okay= 2000 #points= 2000
# theta= [4.00000319e-01 5.99999735e-01 7.68944777e-08] -LogLike= 5265.043914192132 #okay= 2000 #points= 2000
# theta= [4.00000336e-01 5.99999720e-01 6.97979358e-08] -LogLike= 5265.041328370747 #okay= 2000 #points= 2000
# theta= [4.00000346e-01 5.99999720e-01 6.97979358e-08] -LogLike= 5265.041327432584 #okay= 2000 #points= 2000
# theta= [4.00000336e-01 5.99999730e-01 6.97979358e-08] -LogLike= 5265.041329287962 #okay= 2000 #points= 2000
# theta= [4.00000336e-01 5.99999720e-01 7.97979358e-08] -LogLike= 5265.046713547528 #okay= 2000 #points= 2000
# theta= [4.00000339e-01 5.99999718e-01 7.02868245e-08] -LogLike= 5265.041327231172 #okay= 2000 #points= 2000
# theta= [4.00000349e-01 5.99999718e-01 7.02868245e-08] -LogLike= 5265.041326306305 #okay= 2000 #points= 2000
# theta= [4.00000339e-01 5.99999728e-01 7.02868245e-08] -LogLike= 5265.041328140133 #okay= 2000 #points= 2000
# theta= [4.00000339e-01 5.99999718e-01 8.02868245e-08] -LogLike= 5265.047288057328 #okay= 2000 #points= 2000
# theta= [4.00000340e-01 5.99999717e-01 7.03846775e-08] -LogLike= 5265.041270789701 #okay= 2000 #points= 2000
# theta= [4.00000350e-01 5.99999717e-01 7.03846775e-08] -LogLike= 5265.041269895178 #okay= 2000 #points= 2000
# theta= [4.00000340e-01 5.99999727e-01 7.03846775e-08] -LogLike= 5265.041271684756 #okay= 2000 #points= 2000
# theta= [4.00000340e-01 5.99999717e-01 8.03846775e-08] -LogLike= 5265.0474064678265 #okay= 2000 #points= 2000
# theta= [4.00000339e-01 5.99999718e-01 7.03200945e-08] -LogLike= 5265.04132805369 #okay= 2000 #points= 2000
# theta= [4.00000349e-01 5.99999718e-01 7.03200945e-08] -LogLike= 5265.041327153217 #okay= 2000 #points= 2000
# theta= [4.00000339e-01 5.99999728e-01 7.03200945e-08] -LogLike= 5265.041328959147 #okay= 2000 #points= 2000
# theta= [4.00000339e-01 5.99999718e-01 8.03200945e-08] -LogLike= 5265.047328207553 #okay= 2000 #points= 2000
# theta= [4.00000339e-01 5.99999717e-01 7.03799156e-08] -LogLike= 5265.041270530248 #okay= 2000 #points= 2000
# theta= [4.00000349e-01 5.99999717e-01 7.03799156e-08] -LogLike= 5265.041269625933 #okay= 2000 #points= 2000
# theta= [4.00000339e-01 5.99999727e-01 7.03799156e-08] -LogLike= 5265.041271428873 #okay= 2000 #points= 2000
# theta= [4.00000339e-01 5.99999717e-01 8.03799156e-08] -LogLike= 5265.047400688921 #okay= 2000 #points= 2000
# theta= [4.00000339e-01 5.99999718e-01 7.03404337e-08] -LogLike= 5265.041328659341 #okay= 2000 #points= 2000
# theta= [4.00000349e-01 5.99999718e-01 7.03404337e-08] -LogLike= 5265.041327738932 #okay= 2000 #points= 2000
# theta= [4.00000339e-01 5.99999728e-01 7.03404337e-08] -LogLike= 5265.041329554853 #okay= 2000 #points= 2000
# theta= [4.00000339e-01 5.99999718e-01 8.03404337e-08] -LogLike= 5265.047352819755 #okay= 2000 #points= 2000
# theta= [4.00000339e-01 5.99999717e-01 7.03799156e-08] -LogLike= 5265.041270530248 #okay= 2000 #points= 2000
# theta= [4.00000349e-01 5.99999717e-01 7.03799156e-08] -LogLike= 5265.041269625933 #okay= 2000 #points= 2000
# theta= [4.00000339e-01 5.99999727e-01 7.03799156e-08] -LogLike= 5265.041271428873 #okay= 2000 #points= 2000
# theta= [4.00000339e-01 5.99999717e-01 8.03799156e-08] -LogLike= 5265.047400688921 #okay= 2000 #points= 2000
# theta= [4.00000308e-01 5.99999743e-01 6.51304128e-08] -LogLike= 5265.050714727588 #okay= 2000 #points= 2000
# theta= [4.00000318e-01 5.99999743e-01 6.51304128e-08] -LogLike= 5265.0507137476825 #okay= 2000 #points= 2000
# theta= [4.00000308e-01 5.99999753e-01 6.51304128e-08] -LogLike= 5265.050715706288 #okay= 2000 #points= 2000
# theta= [4.00000308e-01 5.99999743e-01 7.51304128e-08] -LogLike= 5265.042715527565 #okay= 2000 #points= 2000
# theta= [4.00000338e-01 5.99999719e-01 7.00898250e-08] -LogLike= 5265.041324673435 #okay= 2000 #points= 2000
# theta= [4.00000348e-01 5.99999719e-01 7.00898250e-08] -LogLike= 5265.041323738255 #okay= 2000 #points= 2000
# theta= [4.00000338e-01 5.99999729e-01 7.00898250e-08] -LogLike= 5265.041325585756 #okay= 2000 #points= 2000
# theta= [4.00000338e-01 5.99999719e-01 8.00898250e-08] -LogLike= 5265.047052594064 #okay= 2000 #points= 2000
# theta= [4.00000339e-01 5.99999718e-01 7.03354862e-08] -LogLike= 5265.041328508385 #okay= 2000 #points= 2000
# theta= [4.00000349e-01 5.99999718e-01 7.03354862e-08] -LogLike= 5265.041327607102 #okay= 2000 #points= 2000
# theta= [4.00000339e-01 5.99999728e-01 7.03354862e-08] -LogLike= 5265.041329429409 #okay= 2000 #points= 2000
# theta= [4.00000339e-01 5.99999718e-01 8.03354862e-08] -LogLike= 5265.047346837677 #okay= 2000 #points= 2000
# theta= [4.00000339e-01 5.99999717e-01 7.03774051e-08] -LogLike= 5265.0412704500595 #okay= 2000 #points= 2000
# theta= [4.00000349e-01 5.99999717e-01 7.03774051e-08] -LogLike= 5265.041269545787 #okay= 2000 #points= 2000
# theta= [4.00000339e-01 5.99999727e-01 7.03774051e-08] -LogLike= 5265.041271307029 #okay= 2000 #points= 2000
# theta= [4.00000339e-01 5.99999717e-01 8.03774051e-08] -LogLike= 5265.047397653761 #okay= 2000 #points= 2000
# theta= [4.00000339e-01 5.99999718e-01 7.03497386e-08] -LogLike= 5265.041328903937 #okay= 2000 #points= 2000
# theta= [4.00000349e-01 5.99999718e-01 7.03497386e-08] -LogLike= 5265.041327993401 #okay= 2000 #points= 2000
# theta= [4.00000339e-01 5.99999728e-01 7.03497386e-08] -LogLike= 5265.041329841045 #okay= 2000 #points= 2000
# theta= [4.00000339e-01 5.99999718e-01 8.03497386e-08] -LogLike= 5265.047364091415 #okay= 2000 #points= 2000
# theta= [4.00000339e-01 5.99999717e-01 7.03763266e-08] -LogLike= 5265.0412703912925 #okay= 2000 #points= 2000
# theta= [4.00000349e-01 5.99999717e-01 7.03763266e-08] -LogLike= 5265.0412694839215 #okay= 2000 #points= 2000
# theta= [4.00000339e-01 5.99999727e-01 7.03763266e-08] -LogLike= 5265.041271293094 #okay= 2000 #points= 2000
# theta= [4.00000339e-01 5.99999717e-01 8.03763266e-08] -LogLike= 5265.047396323245 #okay= 2000 #points= 2000
# theta= [4.00000339e-01 5.99999717e-01 7.03587785e-08] -LogLike= 5265.041269608381 #okay= 2000 #points= 2000
# theta= [4.00000349e-01 5.99999717e-01 7.03587785e-08] -LogLike= 5265.041268713557 #okay= 2000 #points= 2000
# theta= [4.00000339e-01 5.99999727e-01 7.03587785e-08] -LogLike= 5265.041270497546 #okay= 2000 #points= 2000
# theta= [4.00000339e-01 5.99999717e-01 8.03587785e-08] -LogLike= 5265.047375030649 #okay= 2000 #points= 2000
# theta= [4.00000339e-01 5.99999718e-01 7.03528122e-08] -LogLike= 5265.0412693442 #okay= 2000 #points= 2000
# theta= [4.00000349e-01 5.99999718e-01 7.03528122e-08] -LogLike= 5265.041268405642 #okay= 2000 #points= 2000
# theta= [4.00000339e-01 5.99999728e-01 7.03528122e-08] -LogLike= 5265.041270241271 #okay= 2000 #points= 2000
# theta= [4.00000339e-01 5.99999718e-01 8.03528122e-08] -LogLike= 5265.0473678132375 #okay= 2000 #points= 2000
# theta= [4.00000339e-01 5.99999718e-01 7.03507837e-08] -LogLike= 5265.041328925926 #okay= 2000 #points= 2000
# theta= [4.00000349e-01 5.99999718e-01 7.03507837e-08] -LogLike= 5265.041328023802 #okay= 2000 #points= 2000
# theta= [4.00000339e-01 5.99999728e-01 7.03507837e-08] -LogLike= 5265.041329865964 #okay= 2000 #points= 2000
# theta= [4.00000339e-01 5.99999718e-01 8.03507837e-08] -LogLike= 5265.047365335243 #okay= 2000 #points= 2000
# theta= [4.00000339e-01 5.99999718e-01 7.03528122e-08] -LogLike= 5265.0412693442 #okay= 2000 #points= 2000
# theta= [4.00000349e-01 5.99999718e-01 7.03528122e-08] -LogLike= 5265.041268405642 #okay= 2000 #points= 2000
# theta= [4.00000339e-01 5.99999728e-01 7.03528122e-08] -LogLike= 5265.041270241271 #okay= 2000 #points= 2000
# theta= [4.00000339e-01 5.99999718e-01 8.03528122e-08] -LogLike= 5265.0473678132375 #okay= 2000 #points= 2000
# theta= (0.40000043933814383, 0.5999997175255934, 7.03528122056287e-08) -LogLike= 5265.041319909631 #okay= 2000 #points= 2000
# theta= (0.4000002393381438, 0.5999997175255934, 7.03528122056287e-08) -LogLike= 5265.041278414511 #okay= 2000 #points= 2000
# theta= (0.40000033933814383, 0.5999997175255934, 7.03528122056287e-08) -LogLike= 5265.0412693442 #okay= 2000 #points= 2000
# theta= (0.40000033933814383, 0.5999998175255934, 7.03528122056287e-08) -LogLike= 5265.041278420248 #okay= 2000 #points= 2000
# theta= (0.40000033933814383, 0.5999996175255935, 7.03528122056287e-08) -LogLike= 5265.041319903813 #okay= 2000 #points= 2000
# theta= (0.40000033933814383, 0.5999997175255934, 7.03528122056287e-08) -LogLike= 5265.0412693442 #okay= 2000 #points= 2000
# theta= (0.40000033933814383, 0.5999997175255934, 7.135281220562869e-08) -LogLike= 5265.041371240154 #okay= 2000 #points= 2000
# theta= (0.40000033933814383, 0.5999997175255934, 6.93528122056287e-08) -LogLike= 5265.041413532034 #okay= 2000 #points= 2000
# theta= (0.40000033933814383, 0.5999997175255934, 7.03528122056287e-08) -LogLike= 5265.0412693442 #okay= 2000 #points= 2000
# Parameter    Name                                   MLE  Mean         StdErr
# -----------  ------------------------  ----------------  ------  -----------
# T            final time                    53
# a            beta+gamma+delta               0.4                  1.29493e-05
# b            beta*mu                        0.6                  1.29493e-05
# c            beta*mu*rho                    7.03528e-08          6.37468e-08
# R0           R-naught                       1.5
# rho          initial fraction I             1.17255e-07
# tau          epidemic size                  0.582811
# 1-S(T)       rescaling                      0.0143172
# n            #S+#I                     264158
# kT           #I(T)                       3782
# sT           #S(T)                     260376
# kinfty       #I(infty)                 153954
# sinfty       #S(infty)                 110204
# 1/rho        initial total population       8.52844e+06
# gamma        recovery rate
# offset       shift parameter
# \begin{tabular}{llrlr}
# \toprule
#  Parameter   & Name                     &              MLE & Mean   &      StdErr \\
# \midrule
#  T           & final time               &     53           &        &             \\
#  a           & beta+gamma+delta         &      0.4         &        & 1.29493e-05 \\
#  b           & beta*mu                  &      0.6         &        & 1.29493e-05 \\
#  c           & beta*mu*rho              &      7.03528e-08 &        & 6.37468e-08 \\
#  R0          & R-naught                 &      1.5         &        &             \\
#  rho         & initial fraction I       &      1.17255e-07 &        &             \\
#  tau         & epidemic size            &      0.582811    &        &             \\
#  1-S(T)      & rescaling                &      0.0143172   &        &             \\
#  n           & \#S+\#I                    & 264158           &        &             \\
#  kT          & \#I(T)                    &   3782           &        &             \\
#  sT          & \#S(T)                    & 260376           &        &             \\
#  kinfty      & \#I(infty)                & 153954           &        &             \\
#  sinfty      & \#S(infty)                & 110204           &        &             \\
#  1/rho       & initial total population &      8.52844e+06 &        &             \\
#  gamma       & recovery rate            &                  &        &             \\
#  offset      & shift parameter          &                  &        &             \\
# \bottomrule
# \end{tabular}
# sample 4
# theta= [3.99999998e-01 6.00000002e-01 1.34833777e-08] -LogLike= 5141.097297984796 #okay= 2000 #points= 2000
# theta= [4.00000008e-01 6.00000002e-01 1.34833777e-08] -LogLike= 5141.097302076779 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000012e-01 1.34833777e-08] -LogLike= 5141.097293882909 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000002e-01 2.34833777e-08] -LogLike= 5141.210254344956 #okay= 2000 #points= 2000
# theta= [1.e-01 1.e+00 1.e-09] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [1.0000001e-01 1.0000000e+00 1.0000000e-09] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [1.00000000e-01 1.00000001e+00 1.00000000e-09] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [1.0e-01 1.0e+00 1.1e-08] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [3.99985577e-01 6.00019230e-01 1.34827777e-08] -LogLike= 5141.083537108515 #okay= 2000 #points= 2000
# theta= [3.99985587e-01 6.00019230e-01 1.34827777e-08] -LogLike= 5141.083541192442 #okay= 2000 #points= 2000
# theta= [3.99985577e-01 6.00019240e-01 1.34827777e-08] -LogLike= 5141.083532939712 #okay= 2000 #points= 2000
# theta= [3.99985577e-01 6.00019230e-01 2.34827777e-08] -LogLike= 5141.196173404243 #okay= 2000 #points= 2000
# theta= [2.49992789e-01 8.00009615e-01 7.24138883e-09] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [2.49992799e-01 8.00009615e-01 7.24138883e-09] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [2.49992789e-01 8.00009625e-01 7.24138883e-09] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [2.49992789e-01 8.00009615e-01 1.72413888e-08] -LogLike= 13193.747216854586 #okay= 2000 #points= 2000
# theta= [3.99980996e-01 6.00025338e-01 1.34825870e-08] -LogLike= 5141.0791657778 #okay= 2000 #points= 2000
# theta= [3.99981006e-01 6.00025338e-01 1.34825870e-08] -LogLike= 5141.07916984972 #okay= 2000 #points= 2000
# theta= [3.99980996e-01 6.00025348e-01 1.34825870e-08] -LogLike= 5141.079161702751 #okay= 2000 #points= 2000
# theta= [3.99980996e-01 6.00025338e-01 2.34825870e-08] -LogLike= 5141.19171147174 #okay= 2000 #points= 2000
# theta= [3.99663039e-01 6.00449280e-01 1.34693565e-08] -LogLike= 5140.788874771273 #okay= 2000 #points= 2000
# theta= [3.99663049e-01 6.00449280e-01 1.34693565e-08] -LogLike= 5140.788878494498 #okay= 2000 #points= 2000
# theta= [3.99663039e-01 6.00449290e-01 1.34693565e-08] -LogLike= 5140.788871051134 #okay= 2000 #points= 2000
# theta= [3.99663039e-01 6.00449280e-01 2.34693565e-08] -LogLike= 5140.894746185425 #okay= 2000 #points= 2000
# theta= [3.24827914e-01 7.00229448e-01 1.03553726e-08] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [3.24827924e-01 7.00229448e-01 1.03553726e-08] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# ...
# theta= [3.95854383e-01 6.05527498e-01 2.24248138e-08] -LogLike= 5139.230843742079 #okay= 2000 #points= 2000
# theta= [3.95854383e-01 6.05527488e-01 3.24248138e-08] -LogLike= 5139.231640566289 #okay= 2000 #points= 2000
# theta= [3.95854383e-01 6.05527488e-01 2.24248142e-08] -LogLike= 5139.230843731713 #okay= 2000 #points= 2000
# theta= [3.95854393e-01 6.05527488e-01 2.24248142e-08] -LogLike= 5139.230843723733 #okay= 2000 #points= 2000
# theta= [3.95854383e-01 6.05527498e-01 2.24248142e-08] -LogLike= 5139.230843739549 #okay= 2000 #points= 2000
# theta= [3.95854383e-01 6.05527488e-01 3.24248142e-08] -LogLike= 5139.2316405701185 #okay= 2000 #points= 2000
# theta= [3.95854383e-01 6.05527488e-01 2.24248142e-08] -LogLike= 5139.230843731811 #okay= 2000 #points= 2000
# theta= [3.95854393e-01 6.05527488e-01 2.24248142e-08] -LogLike= 5139.230843723859 #okay= 2000 #points= 2000
# theta= [3.95854383e-01 6.05527498e-01 2.24248142e-08] -LogLike= 5139.2308437394495 #okay= 2000 #points= 2000
# theta= [3.95854383e-01 6.05527488e-01 3.24248142e-08] -LogLike= 5139.231640570073 #okay= 2000 #points= 2000
# theta= [3.95854383e-01 6.05527488e-01 2.24248142e-08] -LogLike= 5139.23084373176 #okay= 2000 #points= 2000
# theta= [3.95854393e-01 6.05527488e-01 2.24248142e-08] -LogLike= 5139.230843723737 #okay= 2000 #points= 2000
# theta= [3.95854383e-01 6.05527498e-01 2.24248142e-08] -LogLike= 5139.230843739484 #okay= 2000 #points= 2000
# theta= [3.95854383e-01 6.05527488e-01 3.24248142e-08] -LogLike= 5139.231640570103 #okay= 2000 #points= 2000
# theta= [3.95854383e-01 6.05527488e-01 2.24248142e-08] -LogLike= 5139.230843731713 #okay= 2000 #points= 2000
# theta= [3.95854393e-01 6.05527488e-01 2.24248142e-08] -LogLike= 5139.230843723733 #okay= 2000 #points= 2000
# theta= [3.95854383e-01 6.05527498e-01 2.24248142e-08] -LogLike= 5139.230843739549 #okay= 2000 #points= 2000
# theta= [3.95854383e-01 6.05527488e-01 3.24248142e-08] -LogLike= 5139.2316405701185 #okay= 2000 #points= 2000
# theta= (0.39585448320087535, 0.6055274884100551, 2.2424814216828484e-08) -LogLike= 5139.23084366797 #okay= 2000 #points= 2000
# theta= (0.39585428320087535, 0.6055274884100551, 2.2424814216828484e-08) -LogLike= 5139.2308437877255 #okay= 2000 #points= 2000
# theta= (0.39585438320087535, 0.6055274884100551, 2.2424814216828484e-08) -LogLike= 5139.230843731713 #okay= 2000 #points= 2000
# /Users/khudabukhsh.2/Work/DSA/numerical/wasiur/epidemiccore.py:1528: RuntimeWarning: invalid value encountered in sqrt
#   self.stda = 1/np.sqrt((aa1 - 2*aa3 + aa2)/d**2)
# theta= (0.39585438320087535, 0.605527588410055, 2.2424814216828484e-08) -LogLike= 5139.230843790229 #okay= 2000 #points= 2000
# theta= (0.39585438320087535, 0.6055273884100552, 2.2424814216828484e-08) -LogLike= 5139.230843665574 #okay= 2000 #points= 2000
# theta= (0.39585438320087535, 0.6055274884100551, 2.2424814216828484e-08) -LogLike= 5139.230843731713 #okay= 2000 #points= 2000
# theta= (0.39585438320087535, 0.6055274884100551, 2.3424814216828483e-08) -LogLike= 5139.235964587984 #okay= 2000 #points= 2000
# theta=
# /Users/khudabukhsh.2/Work/DSA/numerical/wasiur/epidemiccore.py:1538: RuntimeWarning: invalid value encountered in sqrt
#   self.stdb = 1/np.sqrt((bb1 - 2*bb3 + bb2)/d**2)
#  (0.39585438320087535, 0.6055274884100551, 2.1424814216828485e-08) -LogLike= 5139.2342987474285 #okay= 2000 #points= 2000
# theta= (0.39585438320087535, 0.6055274884100551, 2.2424814216828484e-08) -LogLike= 5139.230843731713 #okay= 2000 #points= 2000
# Parameter    Name                                   MLE  Mean           StdErr
# -----------  ------------------------  ----------------  ------  -------------
# T            final time                    53
# a            beta+gamma+delta               0.395854             nan
# b            beta*mu                        0.605527             nan
# c            beta*mu*rho                    2.24248e-08            1.07984e-08
# R0           R-naught                       1.52967
# rho          initial fraction I             3.70335e-08
# tau          epidemic size                  0.601551
# 1-S(T)       rescaling                      0.0075287
# n            #S+#I                     502345
# kT           #I(T)                       3782
# sT           #S(T)                     498563
# kinfty       #I(infty)                 302186
# sinfty       #S(infty)                 200159
# 1/rho        initial total population       2.70026e+07
# gamma        recovery rate
# offset       shift parameter
# \begin{tabular}{llrlr}
# \toprule
#  Parameter   & Name                     &              MLE & Mean   &        StdErr \\
# \midrule
#  T           & final time               &     53           &        &               \\
#  a           & beta+gamma+delta         &      0.395854    &        & nan           \\
#  b           & beta*mu                  &      0.605527    &        & nan           \\
#  c           & beta*mu*rho              &      2.24248e-08 &        &   1.07984e-08 \\
#  R0          & R-naught                 &      1.52967     &        &               \\
#  rho         & initial fraction I       &      3.70335e-08 &        &               \\
#  tau         & epidemic size            &      0.601551    &        &               \\
#  1-S(T)      & rescaling                &      0.0075287   &        &               \\
#  n           & \#S+\#I                    & 502345           &        &               \\
#  kT          & \#I(T)                    &   3782           &        &               \\
#  sT          & \#S(T)                    & 498563           &        &               \\
#  kinfty      & \#I(infty)                & 302186           &        &               \\
#  sinfty      & \#S(infty)                & 200159           &        &               \\
#  1/rho       & initial total population &      2.70026e+07 &        &               \\
#  gamma       & recovery rate            &                  &        &               \\
#  offset      & shift parameter          &                  &        &               \\
# \bottomrule
# \end{tabular}
# sample 5
# theta= [3.99999998e-01 6.00000002e-01 1.34833777e-08] -LogLike= 5189.714327887586 #okay= 2000 #points= 2000
# theta= [4.00000008e-01 6.00000002e-01 1.34833777e-08] -LogLike= 5189.71432963132 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000012e-01 1.34833777e-08] -LogLike= 5189.714326139398 #okay= 2000 #points= 2000
# theta= [3.99999998e-01 6.00000002e-01 2.34833777e-08] -LogLike= 5189.681924833977 #okay= 2000 #points= 2000
# theta= [0.1 1.  0.1] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [0.10000001 1.         0.1       ] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [0.1        1.00000001 0.1       ] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [0.1        1.         0.10000001] -LogLike= 1000000.0 #okay= 2000 #points= 2000
# theta= [0.3859903  0.6186796  0.00466991] -LogLike= 15606.052943658371 #okay= 2000 #points= 2000
# theta= [0.38599031 0.6186796  0.00466991] -LogLike= 15606.052617939775 #okay= 2000 #points= 2000
# theta= [0.3859903  0.61867961 0.00466991] -LogLike= 15606.05334981518 #okay= 2000 #points= 2000
# theta= [0.3859903  0.6186796  0.00466992] -LogLike= 15606.05703911195 #okay= 2000 #points= 2000
# theta= [0.39792491 0.60276679 0.00069171] -LogLike= 11262.43873999158 #okay= 2000 #points= 2000
# theta= [0.39792492 0.60276679 0.00069171] -LogLike= 11262.438328295806 #okay= 2000 #points= 2000
# theta= [0.39792491 0.6027668  0.00069171] -LogLike= 11262.43919271844 #okay= 2000 #points= 2000
# theta= [0.39792491 0.60276679 0.00069172] -LogLike= 11262.460899671478 #okay= 2000 #points= 2000
# theta= [3.99883038e-01 6.00155949e-01 3.90001840e-05] -LogLike= 7171.046708681388 #okay= 2000 #points= 2000
# theta= [3.99883048e-01 6.00155949e-01 3.90001840e-05] -LogLike= 7171.046348376151 #okay= 2000 #points= 2000
# theta= [3.99883038e-01 6.00155959e-01 3.90001840e-05] -LogLike= 7171.047085746547 #okay= 2000 #points= 2000
# theta= [3.99883038e-01 6.00155949e-01 3.90101840e-05] -LogLike= 7171.330709893039 #okay= 2000 #points= 2000
# theta= [3.99998527e-01 6.00001964e-01 5.03892617e-07] -LogLike= 5202.414106480793 #okay= 2000 #points= 2000
# theta= [3.99998537e-01 6.00001964e-01 5.03892617e-07] -LogLike= 5202.414107573581 #okay= 2000 #points= 2000
# theta= [3.99998527e-01 6.00001974e-01 5.03892617e-07] -LogLike= 5202.414105732009 #okay= 2000 #points= 2000
# theta= [3.99998527e-01 6.00001964e-01 5.13892617e-07] -LogLike= 5202.852286992141 #okay= 2000 #points= 2000
# theta= [3.99999938e-01 6.00000082e-01 3.35211129e-08] -LogLike= 5189.718982981356 #okay= 2000 #points= 2000
# theta= [3.99999948e-01 6.00000082e-01 3.35211129e-08] -LogLike= 5189.718985044448 #okay= 2000 #points= 2000
# theta= [3.99999938e-01 6.00000092e-01 3.35211129e-08] -LogLike= 5189.718980919012 #okay= 2000 #points= 2000
# theta= [3.99999938e-01 6.00000082e-01 4.35211129e-08] -LogLike= 5189.775098733459 #okay= 2000 #points= 2000
# theta= [3.99999968e-01 6.00000042e-01 2.34383105e-08] -LogLike= 5189.681850505503 #okay= 2000 #points= 2000
# theta= [3.99999978e-01 6.00000042e-01 2.34383105e-08] -LogLike= 5189.681852409687 #okay= 2000 #points= 2000
# theta= [3.99999968e-01 6.00000052e-01 2.34383105e-08] -LogLike= 5189.6818486040365 #okay= 2000 #points= 2000
# theta= [3.99999968e-01 6.00000042e-01 3.34383105e-08] -LogLike= 5189.718613819155 #okay= 2000 #points= 2000
# theta= [3.99999984e-01 6.00000021e-01 1.81488970e-08] -LogLike= 5189.694130933148 #okay= 2000 #points= 2000
# theta= [3.99999994e-01 6.00000021e-01 1.81488970e-08] -LogLike= 5189.6941327570075 #okay= 2000 #points= 2000
# theta= [3.99999984e-01 6.00000031e-01 1.81488970e-08] -LogLike= 5189.69412908774 #okay= 2000 #points= 2000
# theta= [3.99999984e-01 6.00000021e-01 2.81488970e-08] -LogLike= 5189.691265427063 #okay= 2000 #points= 2000
# theta= [3.99999983e-01 6.00000022e-01 1.86035496e-08] -LogLike= 5189.692688725887 #okay= 2000 #points= 2000
# theta= [3.99999993e-01 6.00000022e-01 1.86035496e-08] -LogLike= 5189.692690553193 #okay= 2000 #points= 2000
# theta= [3.99999983e-01 6.00000032e-01 1.86035496e-08] -LogLike= 5189.692686898682 #okay= 2000 #points= 2000
# theta= [3.99999983e-01 6.00000022e-01 2.86035496e-08] -LogLike= 5189.693042455446 #okay= 2000 #points= 2000
# theta= [3.99999983e-01 6.00000022e-01 1.85554082e-08] -LogLike= 5189.692799917102 #okay= 2000 #points= 2000
# theta= [3.99999993e-01 6.00000022e-01 1.85554082e-08] -LogLike= 5189.6928017442815 #okay= 2000 #points= 2000
# theta= [3.99999983e-01 6.00000032e-01 1.85554082e-08] -LogLike= 5189.6927980851915 #okay= 2000 #points= 2000
# theta= [3.99999983e-01 6.00000022e-01 2.85554082e-08] -LogLike= 5189.6928431455035 #okay= 2000 #points= 2000
# theta= [3.99999983e-01 6.00000022e-01 1.86034319e-08] -LogLike= 5189.692688972372 #okay= 2000 #points= 2000
# theta= [3.99999993e-01 6.00000022e-01 1.86034319e-08] -LogLike= 5189.6926908068735 #okay= 2000 #points= 2000
# theta= [3.99999983e-01 6.00000032e-01 1.86034319e-08] -LogLike= 5189.692687146947 #okay= 2000 #points= 2000
# theta= [3.99999983e-01 6.00000022e-01 2.86034319e-08] -LogLike= 5189.693041964991 #okay= 2000 #points= 2000
# theta= [3.99999983e-01 6.00000022e-01 1.86035493e-08] -LogLike= 5189.692688713715 #okay= 2000 #points= 2000
# theta= [3.99999993e-01 6.00000022e-01 1.86035493e-08] -LogLike= 5189.6926905481505 #okay= 2000 #points= 2000
# theta= [3.99999983e-01 6.00000032e-01 1.86035493e-08] -LogLike= 5189.692686887372 #okay= 2000 #points= 2000
# theta= [3.99999983e-01 6.00000022e-01 2.86035493e-08] -LogLike= 5189.693042453895 #okay= 2000 #points= 2000
# theta= [3.99999983e-01 6.00000022e-01 1.86035493e-08] -LogLike= 5189.692688713798 #okay= 2000 #points= 2000
# theta= [3.99999993e-01 6.00000022e-01 1.86035493e-08] -LogLike= 5189.692690548116 #okay= 2000 #points= 2000
# theta= [3.99999983e-01 6.00000032e-01 1.86035493e-08] -LogLike= 5189.692686887541 #okay= 2000 #points= 2000
# theta= [3.99999983e-01 6.00000022e-01 2.86035493e-08] -LogLike= 5189.693042453957 #okay= 2000 #points= 2000
# theta= [3.99999983e-01 6.00000022e-01 1.86035493e-08] -LogLike= 5189.692688713715 #okay= 2000 #points= 2000
# theta= [3.99999993e-01 6.00000022e-01 1.86035493e-08] -LogLike= 5189.6926905481505 #okay= 2000 #points= 2000
# theta= [3.99999983e-01 6.00000032e-01 1.86035493e-08] -LogLike= 5189.692686887372 #okay= 2000 #points= 2000
# theta= [3.99999983e-01 6.00000022e-01 2.86035493e-08] -LogLike= 5189.693042453895 #okay= 2000 #points= 2000
# theta= (0.40000008268852505, 0.6000000224171366, 1.8603549297134834e-08) -LogLike= 5189.6927070896245 #okay= 2000 #points= 2000
# theta= (0.39999988268852504, 0.6000000224171366, 1.8603549297134834e-08) -LogLike= 5189.69267037922 #okay= 2000 #points= 2000
# theta= (0.39999998268852505, 0.6000000224171366, 1.8603549297134834e-08) -LogLike= 5189.692688713715 #okay= 2000 #points= 2000
# theta= (0.39999998268852505, 0.6000001224171365, 1.8603549297134834e-08) -LogLike= 5189.692670392829 #okay= 2000 #points= 2000
# theta= (0.39999998268852505, 0.5999999224171366, 1.8603549297134834e-08) -LogLike= 5189.692707075918 #okay= 2000 #points= 2000
# theta= (0.39999998268852505, 0.6000000224171366, 1.8603549297134834e-08) -LogLike= 5189.692688713715 #okay= 2000 #points= 2000
# theta= (0.39999998268852505, 0.6000000224171366, 1.9603549297134833e-08) -LogLike= 5189.692920785567 #okay= 2000 #points= 2000
# theta= (0.39999998268852505, 0.6000000224171366, 1.7603549297134835e-08) -LogLike= 5189.696306378092 #okay= 2000 #points= 2000
# theta= (0.39999998268852505, 0.6000000224171366, 1.8603549297134834e-08) -LogLike= 5189.692688713715 #okay= 2000 #points= 2000
# Parameter    Name                                   MLE  Mean         StdErr
# -----------  ------------------------  ----------------  ------  -----------
# T            final time                    53
# a            beta+gamma+delta               0.4                  0.000491391
# b            beta*mu                        0.6                  0.000491964
# c            beta*mu*rho                    1.86035e-08          1.6117e-08
# R0           R-naught                       1.5
# rho          initial fraction I             3.10059e-08
# tau          epidemic size                  0.582812
# 1-S(T)       rescaling                      0.00395486
# n            #S+#I                     956291
# kT           #I(T)                       3782
# sT           #S(T)                     952509
# kinfty       #I(infty)                 557338
# sinfty       #S(infty)                 398953
# 1/rho        initial total population       3.22519e+07
# gamma        recovery rate
# offset       shift parameter
# \begin{tabular}{llrlr}
# \toprule
#  Parameter   & Name                     &              MLE & Mean   &      StdErr \\
# \midrule
#  T           & final time               &     53           &        &             \\
#  a           & beta+gamma+delta         &      0.4         &        & 0.000491391 \\
#  b           & beta*mu                  &      0.6         &        & 0.000491964 \\
#  c           & beta*mu*rho              &      1.86035e-08 &        & 1.6117e-08  \\
#  R0          & R-naught                 &      1.5         &        &             \\
#  rho         & initial fraction I       &      3.10059e-08 &        &             \\
#  tau         & epidemic size            &      0.582812    &        &             \\
#  1-S(T)      & rescaling                &      0.00395486  &        &             \\
#  n           & \#S+\#I                    & 956291           &        &             \\
#  kT          & \#I(T)                    &   3782           &        &             \\
#  sT          & \#S(T)                    & 952509           &        &             \\
#  kinfty      & \#I(infty)                & 557338           &        &             \\
#  sinfty      & \#S(infty)                & 398953           &        &             \\
#  1/rho       & initial total population &      3.22519e+07 &        &             \\
#  gamma       & recovery rate            &                  &        &             \\
#  offset      & shift parameter          &                  &        &             \\
# \bottomrule
# \end{tabular}

# %%
fig_density = epiT.plot_density_fit()
fname = 'Tfinaldensityusa'
fig_save(fig_density,Plot_Folder,fname)
# fig_density.savefig(os.path.join (Plot_Folder, fname),dpi=300)
# fig_density.savefig (os.path.join (Plot_Folder, fname + "." + 'pdf'), format='pdf')
# # fig.savefig (os.path.join (Plot_Folder, fname + "." + 'svg'), format='svg')
# fig_density.savefig (os.path.join (Plot_Folder, fname + "." + 'eps'), format='eps', dpi=1000)
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
fig_inf_curve, fig_inf_T = epiT.plot_infections()
fname = 'Tfinalinfectionsusa'
fig_save(fig_inf_T,Plot_Folder,fname)

# %%
fig_dropout = epiT.plot_dropout(pt=epiT.delta/epiT.a)
fname = 'Tfinaldropoutusa'
fig_save(fig_dropout,Plot_Folder,fname)
# fig_inf_T.savefig('../natcommfigures/Tfinalinfectionsusa',dpi=300)
# fig_dropout.savefig('../natcommfigures/Tfinaldropoutusa',dpi=300)

# %%
fig_a, fig_b, fig_c, fig_R0, fig_rho, fig_n, fig_sT, fig_kinfty, fig_sinfty, fig_invrho = epiT.get_histograms()
fname = 'Tfinalausa'
fig_save(fig_a,Plot_Folder,fname)
#fig_a.savefig('../natcommfigures/Tfinalausa',dpi=300)

fname = 'Tfinalbusa'
fig_save(fig_b,Plot_Folder,fname)
#fig_b.savefig('../natcommfigures/Tfinalbusa',dpi=300)

fname = 'Tfinalcusa'
fig_save(fig_c,Plot_Folder,fname)
#fig_c.savefig('../natcommfigures/Tfinalcusa',dpi=300)

fname = 'TfinalR0usa'
fig_save(fig_R0,Plot_Folder,fname)
#fig_R0.savefig('../natcommfigures/TfinalR0usa',dpi=300)

fname = 'Tfinalrhousa'
fig_save(fig_rho,Plot_Folder,fname)
#fig_rho.savefig('../natcommfigures/Tfinalrhousa',dpi=300)

fname = 'Tfinalnusa'
fig_save(fig_n,Plot_Folder,fname)
#fig_n.savefig('../natcommfigures/Tfinalnusa',dpi=300)

fname = 'TfinalsTusa'
fig_save(fig_sT,Plot_Folder,fname)
#fig_sT.savefig('../natcommfigures/TfinalsTusa',dpi=300)

fname = 'Tfinalkinftyusa'
fig_save(fig_kinfty,Plot_Folder,fname)
#fig_kinfty.savefig('../natcommfigures/Tfinalkinftyusa',dpi=300)

fname = 'Tfinalsinftyusa'
fig_save(fig_sinfty,Plot_Folder,fname)
#fig_sinfty.savefig('../natcommfigures/Tfinalsinftyusa',dpi=300)

fname = 'Tfinalinvrhousa'
fig_save(fig_invrho,Plot_Folder,fname)
#fig_invrho.savefig('../natcommfigures/Tfinalinvrhousa',dpi=300)
# Out:
# /Users/khudabukhsh.2/Work/DSA/numerical/wasiur/epidemiccore.py:1482: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fign, ax = plt.subplots()
# /Users/khudabukhsh.2/Work/DSA/numerical/wasiur/epidemiccore.py:1487: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   figsT, ax = plt.subplots()
# /Users/khudabukhsh.2/Work/DSA/numerical/wasiur/epidemiccore.py:1492: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   figkinfty, ax = plt.subplots()
# /Users/khudabukhsh.2/Work/DSA/numerical/wasiur/epidemiccore.py:1497: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   figsinfty, ax = plt.subplots()
# /Users/khudabukhsh.2/Work/DSA/numerical/wasiur/epidemiccore.py:1502: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   figsinvrho, ax = plt.subplots()

# %%
'''
# generate figures for fit at days 20, 30
'''
fig_combined_survival = Epidemic.plot_survival_fits([epiT])
fname = 'survivalsusa'
fig_save(fig_combined_survival, Plot_Folder,fname)
#fig_combined_survival.savefig('../natcommfigures/survivalsusa',dpi=300)
# Out:
# /Users/khudabukhsh.2/Work/DSA/numerical/wasiur/epidemiccore.py:1254: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()

# %%
fig_combined_infection = Epidemic.plot_infection_fits([epiT])
fname = 'infectionsusa'
fig_save(fig_combined_infection, Plot_Folder,fname)
#fig_combined_infection.savefig('../natcommfigures/infectionsusa',dpi=300)
# Out:
# /Users/khudabukhsh.2/Work/DSA/numerical/wasiur/epidemiccore.py:1322: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots()
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
'''
# show optimizer results
'''

print("T=final boundary pts", epiT.number_boundary_samples, "T=final interior pts", epiT.number_interior_samples)
epiT.summary()
plt.show(block=True)
# Out:
# T=final boundary pts 0 T=final interior pts 5
# Parameter    Name                                   MLE              Mean            StdErr
# -----------  ------------------------  ----------------  ----------------  ----------------
# T            final time                    53                53                 0
# a            beta+gamma+delta               0.4               0.399171          0.00165832
# b            beta*mu                        0.6               0.601105          0.00221105
# c            beta*mu*rho                    1.34834e-08       4.70974e-08       2.75863e-08
# R0           R-naught                       1.5               1.50593           0.0118693
# rho          initial fraction I             2.24723e-08       7.84274e-08       4.60384e-08
# tau          epidemic size                  0.582812          0.586559          0.00749602
# 1-S(T)       rescaling                      0.00288521
# n            #S+#I                          1.31082e+06  488552            263069
# kT           #I(T)                       3782              3782                 0
# sT           #S(T)                          1.30704e+06  484770            263069
# kinfty       #I(infty)                 763963            286617            153465
# sinfty       #S(infty)                 546860            201936            109715
# 1/rho        initial total population       4.44992e+07       1.82808e+07       1.00068e+07
# gamma        recovery rate                  0.157586
# offset       shift parameter               -4.99684
# \begin{tabular}{llrrr}
# \toprule
#  Parameter   & Name                     &              MLE &             Mean &           StdErr \\
# \midrule
#  T           & final time               &     53           &     53           &      0           \\
#  a           & beta+gamma+delta         &      0.4         &      0.399171    &      0.00165832  \\
#  b           & beta*mu                  &      0.6         &      0.601105    &      0.00221105  \\
#  c           & beta*mu*rho              &      1.34834e-08 &      4.70974e-08 &      2.75863e-08 \\
#  R0          & R-naught                 &      1.5         &      1.50593     &      0.0118693   \\
#  rho         & initial fraction I       &      2.24723e-08 &      7.84274e-08 &      4.60384e-08 \\
#  tau         & epidemic size            &      0.582812    &      0.586559    &      0.00749602  \\
#  1-S(T)      & rescaling                &      0.00288521  &                  &                  \\
#  n           & \#S+\#I                    &      1.31082e+06 & 488552           & 263069           \\
#  kT          & \#I(T)                    &   3782           &   3782           &      0           \\
#  sT          & \#S(T)                    &      1.30704e+06 & 484770           & 263069           \\
#  kinfty      & \#I(infty)                & 763963           & 286617           & 153465           \\
#  sinfty      & \#S(infty)                & 546860           & 201936           & 109715           \\
#  1/rho       & initial total population &      4.44992e+07 &      1.82808e+07 &      1.00068e+07 \\
#  gamma       & recovery rate            &      0.157586    &                  &                  \\
#  offset      & shift parameter          &     -4.99684     &                  &                  \\
# \bottomrule
# \end{tabular}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-5eed8b4f2b90> in <module>
#       5 print("T=final boundary pts", epiT.number_boundary_samples, "T=final interior pts", epiT.number_interior_samples)
#       6 epiT.summary()
# ----> 7 plt.show(block=True)
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     267     """
#     268     global _show
# --> 269     return _show(*args, **kw)
#     270
#     271
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     411                 "parameter will become keyword-only %(removal)s.",
#     412                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 413         return func(*args, **kwargs)
#     414
#     415     return wrapper
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/backend_bases.py in show(cls, block)
#    3309                 block = True
#    3310         if block:
# -> 3311             cls.mainloop()
#    3312
#    3313     # This method is the one actually exporting the required methods.
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/backends/_backend_tk.py in mainloop()
#     979         managers = Gcf.get_all_fig_managers()
#     980         if managers:
# --> 981             managers[0].window.mainloop()
#
# ~/anaconda3/lib/python3.6/tkinter/__init__.py in mainloop(self, n)
#    1281     def mainloop(self, n=0):
#    1282         """Call the mainloop of Tk."""
# -> 1283         self.tk.mainloop(n)
#    1284     def quit(self):
#    1285         """Quit the Tcl interpreter. All widgets will be destroyed."""
#
# KeyboardInterrupt:
